# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import scipy
import numpy as np
import seaborn as sns

# %% [markdown]
# Objetivos do Script:
#
# Esse script tem como objetivo ler os dados que foram capturados da nossa amostra piloto e realizar alguns estudos em cima desses dados.
#
# Os 6 primeiros tópicos que eu separei abaixo são utilizados na grande maioria dos scripts de tratamento de dados desse estudo.
# Deixei padronizado para que seja possivel tratar simulações com um dispositivo ou vários.
#
# Sumário:
#   - Leitura dos dados
#   - Separar publicações e confirmação de entrega por dispositivo simulado.
#   - Criação de um dataframe com informações capturadas.
#   - Medidas de tendência centrar por dispositivo
#   - Medidas de tendência centrar de todos os dispositivos.
#   - Gráfico de dispersão da amostra.
#   - Calculo do tamanho da amostra.
#
# Como estamos trabalhando com uma amostra piloto temos como objetivo calcular o tamanho das amostras isso será realizado na ultima parte desse script.

# %%
data = pd.read_csv("./data.csv")
ports = data["Source Port"].unique()
ports = ports[ports !=1883]
data
# Out:
#           No.         Time           Source      Destination Protocol  Length  \
# 0          60     0.591828     192.168.15.4  130.185.238.170     MQTT      68
# 1          69     0.665980  130.185.238.170     192.168.15.4     MQTT      68
# 2          92     1.047735     192.168.15.4  130.185.238.170     MQTT      68
# 3          97     1.125143  130.185.238.170     192.168.15.4     MQTT      68
# 4         148     2.290686     192.168.15.4  130.185.238.170     MQTT      68
# ...       ...          ...              ...              ...      ...     ...
# 63062  180074  1027.437646     192.168.15.4  130.185.238.170     MQTT      68
# 63063  180078  1027.506713     192.168.15.4  130.185.238.170     MQTT      68
# 63064  180079  1027.513114  130.185.238.170     192.168.15.4     MQTT      68
# 63065  180091  1027.589645  130.185.238.170     192.168.15.4     MQTT      68
# 63066  180110  1027.818717     192.168.15.4  130.185.238.170     MQTT      68
#
#        Source Port Message Identifier  Destination Port           Info
# 0            42489                NaN              1883   Ping Request
# 1             1883                NaN             42489  Ping Response
# 2            33015                NaN              1883   Ping Request
# 3             1883                NaN             33015  Ping Response
# 4            58245                NaN              1883   Ping Request
# ...            ...                ...               ...            ...
# 63062        56981                NaN              1883   Ping Request
# 63063        49635                NaN              1883   Ping Request
# 63064         1883                NaN             56981  Ping Response
# 63065         1883                NaN             49635  Ping Response
# 63066        38179                NaN              1883   Ping Request
#
# [63067 rows x 10 columns]

# %%
#  - Separar publicações e confirmação de entrega por dispositivo simulado.
devices = {}
#  : devices será um dicionario que irá ter uma chave referente ao device e o valor será um dataframe referente aos respectivos devices 
for port in ports:  
  data = data.loc[ ~(data["Message Identifier"] == "1,2")]
  # data["Message Identifier"].dropna(replace=True)
  array_publish = data.loc[data["Source Port"] == port].dropna(subset=['Message Identifier'])
  array_publish_ack = data.loc[data["Destination Port"] == port].dropna(subset=['Message Identifier'])
  device = {"publish":array_publish, "publish_ack" : array_publish_ack}
  devices[port] = device

# %%
devicesNew = devices.copy()
for index in devices:
    if len(devices[index]["publish"]) <= 0:
        ports = ports[ports !=index]

# %%
# - Criação de um dataframe com informações capturadas acima. 
data = {}
for port in ports:
    RTT = pd.DataFrame(columns=["Time_publish", "Time_ack"])
    for index, row in devices[port]["publish"].iterrows():
        id = int(row["Message Identifier"])
        time_publish = row["Time"]
        RTT.loc[id, "Time_publish"] = time_publish 

    for index, row in devices[port]["publish_ack"].iterrows():
        id = int(row["Message Identifier"])
        time_publish = row["Time"]
        RTT.loc[id, "Time_ack"] = time_publish
    RTT.loc[id, "Time_ack"] = time_publish
    RTT["RTT"]  =(RTT["Time_ack"] - RTT["Time_publish"] )* 1000
    data[port] = RTT

# %% [markdown]
# ## Medidas de Tendência Central Por Device

# %%
i=1
data_mean = []
data_median = []
data_std = []
data_min = []
data_max = []

for port in ports:
  data_mean.append(data[port]["RTT"].mean())
  data_median.append(data[port]["RTT"].mean())
  data_std.append(data[port]["RTT"].mean())
  data_min.append(data[port]["RTT"].mean())
  data_max.append(data[port]["RTT"].mean())

  print("(Device-{})Mean Round Trip Time = {}".format(i ,data[port]["RTT"].mean()))
  print("(Device-{})Median Round Trip Time = {}".format(i ,data[port]["RTT"].median()))
  print("(Device-{})Standard deviation  Round Trip Time = {}".format(i ,data[port]["RTT"].std()))
  print("(Device-{})Min Round Trip Time = {}".format(i ,data[port]["RTT"].min()))
  print("(Device-{})Max Round Trip Time = {}".format(i ,data[port]["RTT"].max()))
  print("---------------------------------------------------------------")

  i+=1
# Out:
# (Device-1)Mean Round Trip Time = 152.78310538694078
# (Device-1)Median Round Trip Time = 151.81981799997857
# (Device-1)Standard deviation  Round Trip Time = 5.342972003529004
# (Device-1)Min Round Trip Time = 149.10423300000275
# (Device-1)Max Round Trip Time = 212.2154620000174
# ---------------------------------------------------------------
# (Device-2)Mean Round Trip Time = 161.31047523114748
# (Device-2)Median Round Trip Time = 159.75574699996287
# (Device-2)Standard deviation  Round Trip Time = 9.64299294997944
# (Device-2)Min Round Trip Time = 157.1551889999796
# (Device-2)Max Round Trip Time = 286.20435099998076
# ---------------------------------------------------------------
# (Device-3)Mean Round Trip Time = 151.39232154271392
# (Device-3)Median Round Trip Time = 150.4665950000117
# (Device-3)Standard deviation  Round Trip Time = 9.249442192206489
# (Device-3)Min Round Trip Time = 144.50106200001755
# (Device-3)Max Round Trip Time = 275.93209199994817
# ---------------------------------------------------------------
# (Device-4)Mean Round Trip Time = 152.1202064271369
# (Device-4)Median Round Trip Time = 150.97687700000506
# (Device-4)Standard deviation  Round Trip Time = 5.264150069807589
# (Device-4)Min Round Trip Time = 146.45474200000308
# (Device-4)Max Round Trip Time = 196.34911200000715
# ---------------------------------------------------------------
# (Device-5)Mean Round Trip Time = 152.54457577387706
# (Device-5)Median Round Trip Time = 151.90926899998658
# (Device-5)Standard deviation  Round Trip Time = 2.675960941609338
# (Device-5)Min Round Trip Time = 149.16321100000118
# (Device-5)Max Round Trip Time = 164.64683000003788
# ---------------------------------------------------------------
# (Device-6)Mean Round Trip Time = 147.14490229145653
# (Device-6)Median Round Trip Time = 145.2394350000077
# (Device-6)Standard deviation  Round Trip Time = 9.99399977093604
# (Device-6)Min Round Trip Time = 142.08901799997875
# (Device-6)Max Round Trip Time = 236.44380399997544
# ---------------------------------------------------------------
# (Device-7)Mean Round Trip Time = 154.68196861306603
# (Device-7)Median Round Trip Time = 152.79286399993453
# (Device-7)Standard deviation  Round Trip Time = 14.003490442518418
# (Device-7)Min Round Trip Time = 149.92614000004778
# (Device-7)Max Round Trip Time = 294.31338700001675
# ---------------------------------------------------------------
# (Device-8)Mean Round Trip Time = 152.86745451758895
# (Device-8)Median Round Trip Time = 152.14542800003983
# (Device-8)Standard deviation  Round Trip Time = 5.696989009275332
# (Device-8)Min Round Trip Time = 149.53941700002815
# (Device-8)Max Round Trip Time = 225.30467800004317
# ---------------------------------------------------------------
# (Device-9)Mean Round Trip Time = 149.93468147738588
# (Device-9)Median Round Trip Time = 148.42022300001645
# (Device-9)Standard deviation  Round Trip Time = 6.979664656169071
# (Device-9)Min Round Trip Time = 143.79466600001933
# (Device-9)Max Round Trip Time = 206.91374199998336
# ---------------------------------------------------------------
# (Device-10)Mean Round Trip Time = 147.23461467839033
# (Device-10)Median Round Trip Time = 146.4353610000444
# (Device-10)Standard deviation  Round Trip Time = 3.0308909860096493
# (Device-10)Min Round Trip Time = 143.44678200001226
# (Device-10)Max Round Trip Time = 158.41617000000952
# ---------------------------------------------------------------
# (Device-11)Mean Round Trip Time = 162.3477040904493
# (Device-11)Median Round Trip Time = 160.5563279999842
# (Device-11)Standard deviation  Round Trip Time = 12.00162124267514
# (Device-11)Min Round Trip Time = 157.68644200011295
# (Device-11)Max Round Trip Time = 321.55192699997315
# ---------------------------------------------------------------
# (Device-12)Mean Round Trip Time = 153.9842767839209
# (Device-12)Median Round Trip Time = 153.1308410000065
# (Device-12)Standard deviation  Round Trip Time = 5.607074533168492
# (Device-12)Min Round Trip Time = 150.14861600002405
# (Device-12)Max Round Trip Time = 222.65390000001162
# ---------------------------------------------------------------
# (Device-13)Mean Round Trip Time = 161.44167649246637
# (Device-13)Median Round Trip Time = 160.58244900000318
# (Device-13)Standard deviation  Round Trip Time = 5.066345274461977
# (Device-13)Min Round Trip Time = 158.04338500004178
# (Device-13)Max Round Trip Time = 221.97880699999928
# ---------------------------------------------------------------
# (Device-14)Mean Round Trip Time = 154.12779524120765
# (Device-14)Median Round Trip Time = 153.4287489999997
# (Device-14)Standard deviation  Round Trip Time = 3.1183312882329757
# (Device-14)Min Round Trip Time = 150.53758500005188
# (Device-14)Max Round Trip Time = 169.65762299992093
# ---------------------------------------------------------------
# (Device-15)Mean Round Trip Time = 154.77822667838825
# (Device-15)Median Round Trip Time = 152.37867100006497
# (Device-15)Standard deviation  Round Trip Time = 18.517757471453645
# (Device-15)Min Round Trip Time = 149.73686600001201
# (Device-15)Max Round Trip Time = 387.1778410000388
# ---------------------------------------------------------------
# (Device-16)Mean Round Trip Time = 158.37334982411798
# (Device-16)Median Round Trip Time = 157.83981499998845
# (Device-16)Standard deviation  Round Trip Time = 4.99373500864552
# (Device-16)Min Round Trip Time = 151.97569999997995
# (Device-16)Max Round Trip Time = 212.32474800000034
# ---------------------------------------------------------------
# (Device-17)Mean Round Trip Time = 162.3826088994975
# (Device-17)Median Round Trip Time = 160.67414300005112
# (Device-17)Standard deviation  Round Trip Time = 10.75362052323002
# (Device-17)Min Round Trip Time = 157.71789299992633
# (Device-17)Max Round Trip Time = 296.1242530000163
# ---------------------------------------------------------------
# (Device-18)Mean Round Trip Time = 152.98483312562743
# (Device-18)Median Round Trip Time = 152.1571240000128
# (Device-18)Standard deviation  Round Trip Time = 4.900730761995612
# (Device-18)Min Round Trip Time = 149.34743799994976
# (Device-18)Max Round Trip Time = 205.60631599994394
# ---------------------------------------------------------------
# (Device-19)Mean Round Trip Time = 154.0332926783905
# (Device-19)Median Round Trip Time = 152.80155099999604
# (Device-19)Standard deviation  Round Trip Time = 8.074916388120451
# (Device-19)Min Round Trip Time = 150.0139360000503
# (Device-19)Max Round Trip Time = 258.4168660000614
# ---------------------------------------------------------------
# (Device-20)Mean Round Trip Time = 161.389754075375
# (Device-20)Median Round Trip Time = 158.6668819999204
# (Device-20)Standard deviation  Round Trip Time = 22.67630345582449
# (Device-20)Min Round Trip Time = 153.04253699997616
# (Device-20)Max Round Trip Time = 462.5715180000043
# ---------------------------------------------------------------
# (Device-21)Mean Round Trip Time = 152.3452916080457
# (Device-21)Median Round Trip Time = 151.25337299997454
# (Device-21)Standard deviation  Round Trip Time = 6.370710270285139
# (Device-21)Min Round Trip Time = 146.74239999999372
# (Device-21)Max Round Trip Time = 232.77168300000994
# ---------------------------------------------------------------
# (Device-22)Mean Round Trip Time = 153.88816024623
# (Device-22)Median Round Trip Time = 152.80440999998746
# (Device-22)Standard deviation  Round Trip Time = 5.653662429579502
# (Device-22)Min Round Trip Time = 149.99202500007414
# (Device-22)Max Round Trip Time = 208.96227100001852
# ---------------------------------------------------------------
# (Device-23)Mean Round Trip Time = 155.1013781507532
# (Device-23)Median Round Trip Time = 152.9840070000006
# (Device-23)Standard deviation  Round Trip Time = 11.079514291530916
# (Device-23)Min Round Trip Time = 150.17215899999314
# (Device-23)Max Round Trip Time = 258.3664889999966
# ---------------------------------------------------------------
# (Device-24)Mean Round Trip Time = 152.5549501608019
# (Device-24)Median Round Trip Time = 151.82898300008674
# (Device-24)Standard deviation  Round Trip Time = 3.218427510447054
# (Device-24)Min Round Trip Time = 149.49811499991483
# (Device-24)Max Round Trip Time = 168.89358699995682
# ---------------------------------------------------------------
# (Device-25)Mean Round Trip Time = 155.24778156784174
# (Device-25)Median Round Trip Time = 153.26646300002267
# (Device-25)Standard deviation  Round Trip Time = 12.683865350082156
# (Device-25)Min Round Trip Time = 150.46015400002943
# (Device-25)Max Round Trip Time = 321.95836099998587
# ---------------------------------------------------------------
# (Device-26)Mean Round Trip Time = 153.1942671557833
# (Device-26)Median Round Trip Time = 152.64057100000628
# (Device-26)Standard deviation  Round Trip Time = 3.012896954311656
# (Device-26)Min Round Trip Time = 149.38071599999603
# (Device-26)Max Round Trip Time = 165.9104040000159
# ---------------------------------------------------------------
# (Device-27)Mean Round Trip Time = 152.3394192562832
# (Device-27)Median Round Trip Time = 151.49136700000554
# (Device-27)Standard deviation  Round Trip Time = 2.8338818561251933
# (Device-27)Min Round Trip Time = 149.04427699997314
# (Device-27)Max Round Trip Time = 163.82286199996088
# ---------------------------------------------------------------
# (Device-28)Mean Round Trip Time = 150.41535818090304
# (Device-28)Median Round Trip Time = 148.16209099990374
# (Device-28)Standard deviation  Round Trip Time = 15.54912360026306
# (Device-28)Min Round Trip Time = 143.7599500000033
# (Device-28)Max Round Trip Time = 315.6843170000059
# ---------------------------------------------------------------
# (Device-29)Mean Round Trip Time = 153.1698922663306
# (Device-29)Median Round Trip Time = 150.45823299999483
# (Device-29)Standard deviation  Round Trip Time = 21.704729793578274
# (Device-29)Min Round Trip Time = 146.66968199992425
# (Device-29)Max Round Trip Time = 439.9119539999674
# ---------------------------------------------------------------
# (Device-30)Mean Round Trip Time = 148.935566361809
# (Device-30)Median Round Trip Time = 146.95202200005042
# (Device-30)Standard deviation  Round Trip Time = 10.1778639285981
# (Device-30)Min Round Trip Time = 143.56233900002735
# (Device-30)Max Round Trip Time = 275.3314889999956
# ---------------------------------------------------------------
# (Device-31)Mean Round Trip Time = 161.75171888944976
# (Device-31)Median Round Trip Time = 160.20560900005876
# (Device-31)Standard deviation  Round Trip Time = 12.120564682324494
# (Device-31)Min Round Trip Time = 157.38102500006335
# (Device-31)Max Round Trip Time = 326.9666129999962
# ---------------------------------------------------------------
# (Device-32)Mean Round Trip Time = 153.1556799396982
# (Device-32)Median Round Trip Time = 152.00928999990992
# (Device-32)Standard deviation  Round Trip Time = 10.17434085487424
# (Device-32)Min Round Trip Time = 149.48439099998723
# (Device-32)Max Round Trip Time = 292.09450800001946
# ---------------------------------------------------------------
# (Device-33)Mean Round Trip Time = 152.62263673366712
# (Device-33)Median Round Trip Time = 150.89974099998926
# (Device-33)Standard deviation  Round Trip Time = 8.201020889867396
# (Device-33)Min Round Trip Time = 148.263868000015
# (Device-33)Max Round Trip Time = 231.8500960000165
# ---------------------------------------------------------------
# (Device-34)Mean Round Trip Time = 160.9677143668321
# (Device-34)Median Round Trip Time = 159.35381199994936
# (Device-34)Standard deviation  Round Trip Time = 9.350728155414247
# (Device-34)Min Round Trip Time = 153.88813199990636
# (Device-34)Max Round Trip Time = 240.08747300001687
# ---------------------------------------------------------------
# (Device-35)Mean Round Trip Time = 153.1587019547756
# (Device-35)Median Round Trip Time = 151.9861279999759
# (Device-35)Standard deviation  Round Trip Time = 7.363633819457618
# (Device-35)Min Round Trip Time = 148.91887800001768
# (Device-35)Max Round Trip Time = 222.95364800004336
# ---------------------------------------------------------------
# (Device-36)Mean Round Trip Time = 154.56863627135382
# (Device-36)Median Round Trip Time = 152.3850080000102
# (Device-36)Standard deviation  Round Trip Time = 12.46699286308703
# (Device-36)Min Round Trip Time = 149.28861500004587
# (Device-36)Max Round Trip Time = 309.976153000008
# ---------------------------------------------------------------
# (Device-37)Mean Round Trip Time = 153.3120609799015
# (Device-37)Median Round Trip Time = 152.04322599998932
# (Device-37)Standard deviation  Round Trip Time = 4.198769908317814
# (Device-37)Min Round Trip Time = 149.1653130000259
# (Device-37)Max Round Trip Time = 189.75737599998865
# ---------------------------------------------------------------
# (Device-38)Mean Round Trip Time = 145.57186965829123
# (Device-38)Median Round Trip Time = 145.0276699999904
# (Device-38)Standard deviation  Round Trip Time = 3.8485813586133575
# (Device-38)Min Round Trip Time = 142.00329100003728
# (Device-38)Max Round Trip Time = 183.30451299999595
# ---------------------------------------------------------------
# (Device-39)Mean Round Trip Time = 146.876644341712
# (Device-39)Median Round Trip Time = 144.98053600004823
# (Device-39)Standard deviation  Round Trip Time = 9.83965724120848
# (Device-39)Min Round Trip Time = 141.98286900000312
# (Device-39)Max Round Trip Time = 262.1960220000119
# ---------------------------------------------------------------
# (Device-40)Mean Round Trip Time = 145.41400145729102
# (Device-40)Median Round Trip Time = 144.59489199998643
# (Device-40)Standard deviation  Round Trip Time = 2.890398895569176
# (Device-40)Min Round Trip Time = 141.62216699992314
# (Device-40)Max Round Trip Time = 155.97420799997508
# ---------------------------------------------------------------
# (Device-41)Mean Round Trip Time = 150.89752187939447
# (Device-41)Median Round Trip Time = 150.22887600002832
# (Device-41)Standard deviation  Round Trip Time = 2.930827420435411
# (Device-41)Min Round Trip Time = 144.62951399997337
# (Device-41)Max Round Trip Time = 161.32445100004134
# ---------------------------------------------------------------
# (Device-42)Mean Round Trip Time = 152.38851278391874
# (Device-42)Median Round Trip Time = 150.64736799999423
# (Device-42)Standard deviation  Round Trip Time = 16.776338643383763
# (Device-42)Min Round Trip Time = 144.49355599998626
# (Device-42)Max Round Trip Time = 368.34168699999736
# ---------------------------------------------------------------
# (Device-43)Mean Round Trip Time = 151.4031288994969
# (Device-43)Median Round Trip Time = 150.89509100005216
# (Device-43)Standard deviation  Round Trip Time = 2.84116233397782
# (Device-43)Min Round Trip Time = 144.54752699998608
# (Device-43)Max Round Trip Time = 164.03740000004063
# ---------------------------------------------------------------
# (Device-44)Mean Round Trip Time = 154.18264024622874
# (Device-44)Median Round Trip Time = 152.1810720000758
# (Device-44)Standard deviation  Round Trip Time = 11.793050585340662
# (Device-44)Min Round Trip Time = 149.60888099994918
# (Device-44)Max Round Trip Time = 305.5108159999236
# ---------------------------------------------------------------
# (Device-45)Mean Round Trip Time = 156.06824771858962
# (Device-45)Median Round Trip Time = 152.63149499998008
# (Device-45)Standard deviation  Round Trip Time = 27.197002344951283
# (Device-45)Min Round Trip Time = 149.97713799994017
# (Device-45)Max Round Trip Time = 447.13018800007376
# ---------------------------------------------------------------
# (Device-46)Mean Round Trip Time = 162.67781238191102
# (Device-46)Median Round Trip Time = 160.18654799995602
# (Device-46)Standard deviation  Round Trip Time = 17.35319719442782
# (Device-46)Min Round Trip Time = 157.56477200000063
# (Device-46)Max Round Trip Time = 370.1418340000373
# ---------------------------------------------------------------
# (Device-47)Mean Round Trip Time = 151.06500336181168
# (Device-47)Median Round Trip Time = 150.54091599995445
# (Device-47)Standard deviation  Round Trip Time = 2.876201744379718
# (Device-47)Min Round Trip Time = 144.56688400002804
# (Device-47)Max Round Trip Time = 164.1687159999492
# ---------------------------------------------------------------
# (Device-48)Mean Round Trip Time = 146.33334057789153
# (Device-48)Median Round Trip Time = 144.8189000000184
# (Device-48)Standard deviation  Round Trip Time = 8.321429477835961
# (Device-48)Min Round Trip Time = 142.1523100000286
# (Device-48)Max Round Trip Time = 235.9242009999889
# ---------------------------------------------------------------
# (Device-49)Mean Round Trip Time = 146.29598815577927
# (Device-49)Median Round Trip Time = 144.7099160000107
# (Device-49)Standard deviation  Round Trip Time = 8.195719461036143
# (Device-49)Min Round Trip Time = 142.27244999995037
# (Device-49)Max Round Trip Time = 251.3518360000262
# ---------------------------------------------------------------
# (Device-50)Mean Round Trip Time = 148.2610779748739
# (Device-50)Median Round Trip Time = 146.8871859999865
# (Device-50)Standard deviation  Round Trip Time = 7.549965245084297
# (Device-50)Min Round Trip Time = 143.73733999997285
# (Device-50)Max Round Trip Time = 243.5851120000052
# ---------------------------------------------------------------
# (Device-51)Mean Round Trip Time = 152.9358778241187
# (Device-51)Median Round Trip Time = 152.00060699999085
# (Device-51)Standard deviation  Round Trip Time = 4.1338993451813195
# (Device-51)Min Round Trip Time = 149.71479199994064
# (Device-51)Max Round Trip Time = 199.07612400004382
# ---------------------------------------------------------------
# (Device-52)Mean Round Trip Time = 155.45469034170318
# (Device-52)Median Round Trip Time = 153.2672239999897
# (Device-52)Standard deviation  Round Trip Time = 12.670105249894105
# (Device-52)Min Round Trip Time = 150.40639599999395
# (Device-52)Max Round Trip Time = 279.81022299999836
# ---------------------------------------------------------------
# (Device-53)Mean Round Trip Time = 145.95772206029804
# (Device-53)Median Round Trip Time = 144.77516400000923
# (Device-53)Standard deviation  Round Trip Time = 5.501103547017422
# (Device-53)Min Round Trip Time = 142.20077999999603
# (Device-53)Max Round Trip Time = 210.3569459999335
# ---------------------------------------------------------------
# (Device-54)Mean Round Trip Time = 152.4863288693458
# (Device-54)Median Round Trip Time = 151.58148599994092
# (Device-54)Standard deviation  Round Trip Time = 3.486610360701291
# (Device-54)Min Round Trip Time = 149.11151799992695
# (Device-54)Max Round Trip Time = 180.21871500002362
# ---------------------------------------------------------------
# (Device-55)Mean Round Trip Time = 152.34527491457146
# (Device-55)Median Round Trip Time = 150.71857699996372
# (Device-55)Standard deviation  Round Trip Time = 11.610631233897218
# (Device-55)Min Round Trip Time = 147.4889699999835
# (Device-55)Max Round Trip Time = 293.554419999964
# ---------------------------------------------------------------
# (Device-56)Mean Round Trip Time = 153.3725806281389
# (Device-56)Median Round Trip Time = 152.5266769999689
# (Device-56)Standard deviation  Round Trip Time = 3.271857078858572
# (Device-56)Min Round Trip Time = 149.71951500001524
# (Device-56)Max Round Trip Time = 171.33341400005975
# ---------------------------------------------------------------
# (Device-57)Mean Round Trip Time = 154.10636484924288
# (Device-57)Median Round Trip Time = 152.51334099997393
# (Device-57)Standard deviation  Round Trip Time = 12.600873395002811
# (Device-57)Min Round Trip Time = 149.83702499989704
# (Device-57)Max Round Trip Time = 325.20599700001185
# ---------------------------------------------------------------
# (Device-58)Mean Round Trip Time = 155.72704072864363
# (Device-58)Median Round Trip Time = 152.61729200005902
# (Device-58)Standard deviation  Round Trip Time = 23.2634801841386
# (Device-58)Min Round Trip Time = 150.08031200000005
# (Device-58)Max Round Trip Time = 441.25384100004794
# ---------------------------------------------------------------
# (Device-59)Mean Round Trip Time = 146.02319330150718
# (Device-59)Median Round Trip Time = 145.1419799999769
# (Device-59)Standard deviation  Round Trip Time = 7.306586926653349
# (Device-59)Min Round Trip Time = 142.51811900010125
# (Device-59)Max Round Trip Time = 242.03033300000243
# ---------------------------------------------------------------
# (Device-60)Mean Round Trip Time = 153.53341600502253
# (Device-60)Median Round Trip Time = 151.98096500000702
# (Device-60)Standard deviation  Round Trip Time = 6.386767863000515
# (Device-60)Min Round Trip Time = 149.45606799994948
# (Device-60)Max Round Trip Time = 219.6626349999633
# ---------------------------------------------------------------
# (Device-61)Mean Round Trip Time = 152.86021517085567
# (Device-61)Median Round Trip Time = 152.07727500001056
# (Device-61)Standard deviation  Round Trip Time = 4.083688755085725
# (Device-61)Min Round Trip Time = 148.38257999997495
# (Device-61)Max Round Trip Time = 192.68937700007882
# ---------------------------------------------------------------
# (Device-62)Mean Round Trip Time = 154.93490989447557
# (Device-62)Median Round Trip Time = 152.83491399998184
# (Device-62)Standard deviation  Round Trip Time = 10.253091584334745
# (Device-62)Min Round Trip Time = 149.9527329999637
# (Device-62)Max Round Trip Time = 263.8350349999996
# ---------------------------------------------------------------
# (Device-63)Mean Round Trip Time = 153.205718592968
# (Device-63)Median Round Trip Time = 152.58925300003057
# (Device-63)Standard deviation  Round Trip Time = 4.680346710371924
# (Device-63)Min Round Trip Time = 149.56342600009975
# (Device-63)Max Round Trip Time = 207.89791000004243
# ---------------------------------------------------------------
# (Device-64)Mean Round Trip Time = 153.74110297487195
# (Device-64)Median Round Trip Time = 152.46833900002343
# (Device-64)Standard deviation  Round Trip Time = 5.645558865746268
# (Device-64)Min Round Trip Time = 149.46466499998223
# (Device-64)Max Round Trip Time = 201.82787899989307
# ---------------------------------------------------------------
# (Device-65)Mean Round Trip Time = 161.7400242311532
# (Device-65)Median Round Trip Time = 160.5665739999722
# (Device-65)Standard deviation  Round Trip Time = 9.193590267558053
# (Device-65)Min Round Trip Time = 157.8433079999968
# (Device-65)Max Round Trip Time = 285.31848499994794
# ---------------------------------------------------------------
# (Device-66)Mean Round Trip Time = 155.04814579397035
# (Device-66)Median Round Trip Time = 152.37470900001426
# (Device-66)Standard deviation  Round Trip Time = 23.218808041267593
# (Device-66)Min Round Trip Time = 149.84230400000342
# (Device-66)Max Round Trip Time = 460.8182570000281
# ---------------------------------------------------------------
# (Device-67)Mean Round Trip Time = 161.3520820050248
# (Device-67)Median Round Trip Time = 160.4560450000463
# (Device-67)Standard deviation  Round Trip Time = 4.781813475270962
# (Device-67)Min Round Trip Time = 157.55958800002645
# (Device-67)Max Round Trip Time = 213.71101399995496
# ---------------------------------------------------------------
# (Device-68)Mean Round Trip Time = 153.35434940201205
# (Device-68)Median Round Trip Time = 152.9283930000247
# (Device-68)Standard deviation  Round Trip Time = 2.4700418892445297
# (Device-68)Min Round Trip Time = 150.108648000014
# (Device-68)Max Round Trip Time = 164.19358300004205
# ---------------------------------------------------------------
# (Device-69)Mean Round Trip Time = 153.39547216080294
# (Device-69)Median Round Trip Time = 151.94984200002182
# (Device-69)Standard deviation  Round Trip Time = 13.05428947979314
# (Device-69)Min Round Trip Time = 149.24087500000383
# (Device-69)Max Round Trip Time = 331.87015799998676
# ---------------------------------------------------------------
# (Device-70)Mean Round Trip Time = 154.21323236180655
# (Device-70)Median Round Trip Time = 152.81134099998894
# (Device-70)Standard deviation  Round Trip Time = 8.487151736518825
# (Device-70)Min Round Trip Time = 149.74366199999167
# (Device-70)Max Round Trip Time = 264.4254650000448
# ---------------------------------------------------------------
# (Device-71)Mean Round Trip Time = 161.77880321608228
# (Device-71)Median Round Trip Time = 159.74492200001578
# (Device-71)Standard deviation  Round Trip Time = 13.87284175591844
# (Device-71)Min Round Trip Time = 157.0780189999823
# (Device-71)Max Round Trip Time = 306.60673200009114
# ---------------------------------------------------------------
# (Device-72)Mean Round Trip Time = 151.8997775628136
# (Device-72)Median Round Trip Time = 151.15896800000428
# (Device-72)Standard deviation  Round Trip Time = 3.9230322447433017
# (Device-72)Min Round Trip Time = 148.6001119999969
# (Device-72)Max Round Trip Time = 194.79363199997124
# ---------------------------------------------------------------
# (Device-73)Mean Round Trip Time = 152.99046125125685
# (Device-73)Median Round Trip Time = 151.91703299996107
# (Device-73)Standard deviation  Round Trip Time = 6.05950924485405
# (Device-73)Min Round Trip Time = 149.16119899999103
# (Device-73)Max Round Trip Time = 224.7836679999864
# ---------------------------------------------------------------
# (Device-74)Mean Round Trip Time = 161.83484061808838
# (Device-74)Median Round Trip Time = 160.71021999994173
# (Device-74)Standard deviation  Round Trip Time = 8.191743851851651
# (Device-74)Min Round Trip Time = 158.0421229999729
# (Device-74)Max Round Trip Time = 269.83835900000486
# ---------------------------------------------------------------
# (Device-75)Mean Round Trip Time = 158.36699989949872
# (Device-75)Median Round Trip Time = 158.0662439999969
# (Device-75)Standard deviation  Round Trip Time = 5.396286481301176
# (Device-75)Min Round Trip Time = 152.01840899999297
# (Device-75)Max Round Trip Time = 216.38033700003234
# ---------------------------------------------------------------
# (Device-76)Mean Round Trip Time = 152.93506992462338
# (Device-76)Median Round Trip Time = 152.51828599997452
# (Device-76)Standard deviation  Round Trip Time = 2.678192699640323
# (Device-76)Min Round Trip Time = 149.40458600000284
# (Device-76)Max Round Trip Time = 168.35630100001708
# ---------------------------------------------------------------
# (Device-77)Mean Round Trip Time = 148.99285121105567
# (Device-77)Median Round Trip Time = 145.21681500002614
# (Device-77)Standard deviation  Round Trip Time = 26.235224727564308
# (Device-77)Min Round Trip Time = 142.53798300001108
# (Device-77)Max Round Trip Time = 445.89905700001964
# ---------------------------------------------------------------
# (Device-78)Mean Round Trip Time = 146.15588466331863
# (Device-78)Median Round Trip Time = 144.6810769999729
# (Device-78)Standard deviation  Round Trip Time = 8.473487072182445
# (Device-78)Min Round Trip Time = 141.52715299996999
# (Device-78)Max Round Trip Time = 255.43432500001018
# ---------------------------------------------------------------
# (Device-79)Mean Round Trip Time = 150.60064608542592
# (Device-79)Median Round Trip Time = 150.25629000001572
# (Device-79)Standard deviation  Round Trip Time = 3.8562192128033055
# (Device-79)Min Round Trip Time = 144.2828349999843
# (Device-79)Max Round Trip Time = 179.11120699997696
# ---------------------------------------------------------------
# (Device-80)Mean Round Trip Time = 161.73106070853984
# (Device-80)Median Round Trip Time = 160.2366120000056
# (Device-80)Standard deviation  Round Trip Time = 12.248357060280956
# (Device-80)Min Round Trip Time = 157.16864900002747
# (Device-80)Max Round Trip Time = 324.1605599999957
# ---------------------------------------------------------------
# (Device-81)Mean Round Trip Time = 151.30571692462485
# (Device-81)Median Round Trip Time = 150.52002699997047
# (Device-81)Standard deviation  Round Trip Time = 3.1236318598495885
# (Device-81)Min Round Trip Time = 145.2211560000478
# (Device-81)Max Round Trip Time = 163.873370000033
# ---------------------------------------------------------------
# (Device-82)Mean Round Trip Time = 152.17199147236263
# (Device-82)Median Round Trip Time = 150.72678699999642
# (Device-82)Standard deviation  Round Trip Time = 5.398428222247107
# (Device-82)Min Round Trip Time = 148.36864900001956
# (Device-82)Max Round Trip Time = 191.82570099997065
# ---------------------------------------------------------------
# (Device-83)Mean Round Trip Time = 151.12145523115214
# (Device-83)Median Round Trip Time = 150.2987900000221
# (Device-83)Standard deviation  Round Trip Time = 6.5672293059723
# (Device-83)Min Round Trip Time = 144.9375739999823
# (Device-83)Max Round Trip Time = 227.60072099998752
# ---------------------------------------------------------------
# (Device-84)Mean Round Trip Time = 146.570518271351
# (Device-84)Median Round Trip Time = 144.21880800000508
# (Device-84)Standard deviation  Round Trip Time = 16.368763034759677
# (Device-84)Min Round Trip Time = 141.81690600003094
# (Device-84)Max Round Trip Time = 327.7667999999494
# ---------------------------------------------------------------
# (Device-85)Mean Round Trip Time = 154.96319492964477
# (Device-85)Median Round Trip Time = 152.622354000016
# (Device-85)Standard deviation  Round Trip Time = 15.759259769834934
# (Device-85)Min Round Trip Time = 149.6720100000175
# (Device-85)Max Round Trip Time = 312.61531799998465
# ---------------------------------------------------------------
# (Device-86)Mean Round Trip Time = 154.76062273869368
# (Device-86)Median Round Trip Time = 152.96484300000657
# (Device-86)Standard deviation  Round Trip Time = 9.663200699595414
# (Device-86)Min Round Trip Time = 150.12085199998637
# (Device-86)Max Round Trip Time = 255.8882299999823
# ---------------------------------------------------------------
# (Device-87)Mean Round Trip Time = 145.68128359296784
# (Device-87)Median Round Trip Time = 144.5180610000989
# (Device-87)Standard deviation  Round Trip Time = 4.6654591761763955
# (Device-87)Min Round Trip Time = 141.93732300009287
# (Device-87)Max Round Trip Time = 188.37448099998255
# ---------------------------------------------------------------
# (Device-88)Mean Round Trip Time = 150.3221096984932
# (Device-88)Median Round Trip Time = 150.01122000001033
# (Device-88)Standard deviation  Round Trip Time = 3.675812775797787
# (Device-88)Min Round Trip Time = 144.18480899996666
# (Device-88)Max Round Trip Time = 166.43856199993934
# ---------------------------------------------------------------
# (Device-89)Mean Round Trip Time = 153.9292543969818
# (Device-89)Median Round Trip Time = 152.0155059999979
# (Device-89)Standard deviation  Round Trip Time = 12.359181726469265
# (Device-89)Min Round Trip Time = 149.6493889999897
# (Device-89)Max Round Trip Time = 284.9046400000361
# ---------------------------------------------------------------
# (Device-90)Mean Round Trip Time = 148.84677012060305
# (Device-90)Median Round Trip Time = 145.15879999999015
# (Device-90)Standard deviation  Round Trip Time = 25.26523466843194
# (Device-90)Min Round Trip Time = 142.426692000015
# (Device-90)Max Round Trip Time = 454.5263940000268
# ---------------------------------------------------------------
# (Device-91)Mean Round Trip Time = 151.45667015577922
# (Device-91)Median Round Trip Time = 150.63967900005082
# (Device-91)Standard deviation  Round Trip Time = 6.841222852376932
# (Device-91)Min Round Trip Time = 144.46574699991288
# (Device-91)Max Round Trip Time = 238.21847499993964
# ---------------------------------------------------------------
# (Device-92)Mean Round Trip Time = 153.33945640703465
# (Device-92)Median Round Trip Time = 151.9835439999042
# (Device-92)Standard deviation  Round Trip Time = 9.56235360949625
# (Device-92)Min Round Trip Time = 149.29811300004303
# (Device-92)Max Round Trip Time = 276.00694099999146
# ---------------------------------------------------------------
# (Device-93)Mean Round Trip Time = 153.43831865326837
# (Device-93)Median Round Trip Time = 152.01490300000842
# (Device-93)Standard deviation  Round Trip Time = 8.062137974989529
# (Device-93)Min Round Trip Time = 149.4003090000433
# (Device-93)Max Round Trip Time = 240.45259699994403
# ---------------------------------------------------------------
# (Device-94)Mean Round Trip Time = 146.34028789949312
# (Device-94)Median Round Trip Time = 144.604500000014
# (Device-94)Standard deviation  Round Trip Time = 10.95386765403045
# (Device-94)Min Round Trip Time = 141.62524799996845
# (Device-94)Max Round Trip Time = 276.2384809999503
# ---------------------------------------------------------------
# (Device-95)Mean Round Trip Time = 153.26226697487886
# (Device-95)Median Round Trip Time = 152.15866500000175
# (Device-95)Standard deviation  Round Trip Time = 7.001040999131783
# (Device-95)Min Round Trip Time = 149.09126999998534
# (Device-95)Max Round Trip Time = 240.11985200002073
# ---------------------------------------------------------------
# (Device-96)Mean Round Trip Time = 154.5635403668326
# (Device-96)Median Round Trip Time = 152.1417050000764
# (Device-96)Standard deviation  Round Trip Time = 16.697803620880162
# (Device-96)Min Round Trip Time = 149.52855400002818
# (Device-96)Max Round Trip Time = 347.95826000004126
# ---------------------------------------------------------------
# (Device-97)Mean Round Trip Time = 161.61310758292
# (Device-97)Median Round Trip Time = 159.39581399993585
# (Device-97)Standard deviation  Round Trip Time = 18.354235855063067
# (Device-97)Min Round Trip Time = 156.54230200004804
# (Device-97)Max Round Trip Time = 370.40608500001326
# ---------------------------------------------------------------
# (Device-98)Mean Round Trip Time = 162.24210843215613
# (Device-98)Median Round Trip Time = 160.7710709999992
# (Device-98)Standard deviation  Round Trip Time = 10.73155580814733
# (Device-98)Min Round Trip Time = 157.9595490001111
# (Device-98)Max Round Trip Time = 305.228335999999
# ---------------------------------------------------------------
# (Device-99)Mean Round Trip Time = 152.2255047789
# (Device-99)Median Round Trip Time = 151.2702360000162
# (Device-99)Standard deviation  Round Trip Time = 6.876534145449923
# (Device-99)Min Round Trip Time = 148.31574400000136
# (Device-99)Max Round Trip Time = 242.23083399999723
# ---------------------------------------------------------------
# (Device-100)Mean Round Trip Time = 146.0748980150717
# (Device-100)Median Round Trip Time = 144.96228999999516
# (Device-100)Standard deviation  Round Trip Time = 4.630597831212494
# (Device-100)Min Round Trip Time = 142.23753199996736
# (Device-100)Max Round Trip Time = 182.42494200001147
# ---------------------------------------------------------------

# %% [markdown]
# # CÁLCULO DO TAMANHO DA AMOSTRA

# %%
nivel_de_significancia = 0.05

# %%
nivel_de_confiança = 1 - nivel_de_significancia
nivel_de_confiança
# Out:
# 0.95

# %%
#Calculando o z com scipy
z = scipy.stats.norm.ppf(0.975)
z
# Out:
# 1.959963984540054

# %% [markdown]
# Com nosso z calculado podemos seguir adiante
#
# ### $$z = 1.959963984540054 $$
#
# Abaixo segue algumas formulas que iremos utilizar para calcular o numero de amostra

# %% [markdown]
# ### Calculando o tamanho da nossa amostra

# %%
df_concatenado = pd.concat(data.values())
desvio_padrao_amostral = df_concatenado["RTT"].std()
media = df_concatenado["RTT"].mean()
e = 0.05 * media
n = (z * ( desvio_padrao_amostral/e) )**2
n
# Out:
# 8.966300464455099

# %%
e = df_concatenado["RTT"].mean() * 0.05

# %%
desvio_padrao_amostral
# Out:
# 11.717496594732564

# %%
import matplotlib 
i=1
fig, ax = plt.subplots(figsize=(10,5),dpi=72)
for port in ports:
  ax.scatter(data[port]["RTT"].index,data[port]["RTT"], label='Dispositivo-{}'.format(i))
  ax.set_ylabel('Round Trip Time (ms)')
  ax.set_xlabel('Quantidade de Publicação')
  ax.set_title('Gráfico de dispersão (Round Trip Time)')
#   ax.hlines(data[port]["RTT"].max(),  xmin=0, xmax=620, colors="red", linestyles="dashed", label="Maior Medição")
#   ax.hlines(data[port]["RTT"].min(),  xmin=0, xmax=620, colors="green", linestyles="dashed", label="Menor Medição")
  ax.legend()
  i+=1

# %%
df_concatenado["RTT"].mean()
# Out:
# 153.3932604125121

# %%
df_concatenado["RTT"].to_csv("dados.csv", index=False)
