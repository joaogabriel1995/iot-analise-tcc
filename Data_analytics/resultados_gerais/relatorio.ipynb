# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import scipy
import numpy as np
import seaborn as sns

# %%
# data1 = pd.read_csv("../device-1-sizepayload-6-msg-200/dados.csv")
# data1["device"] = 1
# data1["size"] = 6

# data2 = pd.read_csv("../device-1-sizepayload-256-msg-200/dados.csv")
# data2["device"] = 1

data3 = pd.read_csv("../device-5-sizepayload-6-msg-200/dados.csv")
data3["device"] = 5
data3["size"] = 6

data4 = pd.read_csv("../device-5-sizepayload-256-msg-200/dados.csv")
data4["device"] = 5
data4["size"] = 256

data5 = pd.read_csv("../device-20-sizepayload-6-msg-200/dados.csv")
data5["device"] = 20
data5["size"] = 6

data6 = pd.read_csv("../device-20-sizepayload-256-msg-200/dados.csv")
data6["device"] = 20
data6["size"] = 256


data7 = pd.read_csv("../device-50-sizepayload-6-msg-200/dados.csv")
data7["device"] = 50
data7["size"] = 6

data8 = pd.read_csv("../device-50-sizepayload-256-msg-200/dados.csv")
data8["device"] = 50
data8["size"] = 256


data9 = pd.read_csv("../device-100-sizepayload-6-msg-200/dados.csv")
data9["device"] = 100
data9["size"] = 6

data10 = pd.read_csv("../device-100-sizepayload-256-msg-200/dados.csv")
data10["device"] = 100
data10["size"] = 256


data = [data3,data4, data5, data6, data7,data8,data9,data10]

# %%
array = []
for i in data:

    array.append((i["device"].mean(), i["RTT"].mean().round(2),i["size"].mean()))

    print("device", i["device"].mean())
    print("size", i["size"].mean())
    print("média", i["RTT"].mean().round(2))
    print("----------------------------")
# Out:
# device 5.0
# size 6.0
# média 159.6
# ----------------------------
# device 5.0
# size 256.0
# média 161.95
# ----------------------------
# device 20.0
# size 6.0
# média 154.87
# ----------------------------
# device 20.0
# size 256.0
# média 156.14
# ----------------------------
# device 50.0
# size 6.0
# média 155.86
# ----------------------------
# device 50.0
# size 256.0
# média 156.5
# ----------------------------
# device 100.0
# size 6.0
# média 153.39
# ----------------------------
# device 100.0
# size 256.0
# média 153.4
# ----------------------------

# %%
import matplotlib 
size_256 = []
size_6 =[]
fig, ax = plt.subplots(figsize=(10,5),dpi=72)
ax.grid()
for i in array:
  if (i[2] === 256):
    size_256 = i
  ax.scatter(i[0],i[1], label='Dispositivo-{}'.format(i))
  ax.legend()
  # i+=1
# Out:
# 159.6
# 161.95
# 154.87
# 156.14
# 155.86
# 156.5
# 153.39
# 153.4

# %%
# Out:
# (5.0, 159.6, 6.0)
