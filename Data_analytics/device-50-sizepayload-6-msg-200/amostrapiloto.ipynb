# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import scipy
import numpy as np
import seaborn as sns

# %% [markdown]
# Objetivos do Script:
#
# Esse script tem como objetivo ler os dados que foram capturados da nossa amostra piloto e realizar alguns estudos em cima desses dados.
#
# Os 6 primeiros tópicos que eu separei abaixo são utilizados na grande maioria dos scripts de tratamento de dados desse estudo.
# Deixei padronizado para que seja possivel tratar simulações com um dispositivo ou vários.
#
# Sumário:
#   - Leitura dos dados
#   - Separar publicações e confirmação de entrega por dispositivo simulado.
#   - Criação de um dataframe com informações capturadas.
#   - Medidas de tendência centrar por dispositivo
#   - Medidas de tendência centrar de todos os dispositivos.
#   - Gráfico de dispersão da amostra.
#   - Calculo do tamanho da amostra.
#
# Como estamos trabalhando com uma amostra piloto temos como objetivo calcular o tamanho das amostras isso será realizado na ultima parte desse script.

# %%
data = pd.read_csv("./data.csv")
ports = data["Source Port"].unique()
ports = ports[ports !=1883]
data
# Out:
#           No.        Time           Source      Destination Protocol  Length  \
# 0          89   11.096193     192.168.15.8  130.185.238.170     MQTT      89
# 1          91   11.172041  130.185.238.170     192.168.15.8     MQTT      70
# 2          92   11.172077     192.168.15.8  130.185.238.170     MQTT     103
# 3          94   11.247474  130.185.238.170     192.168.15.8     MQTT      71
# 4          99   11.323609  130.185.238.170     192.168.15.8     MQTT      89
# ...       ...         ...              ...              ...      ...     ...
# 31460  207607  890.914385  130.185.238.170     192.168.15.8     MQTT      68
# 31461  207609  891.198228     192.168.15.8  130.185.238.170     MQTT      68
# 31462  207610  891.273487  130.185.238.170     192.168.15.8     MQTT      68
# 31463  207612  891.696205     192.168.15.8  130.185.238.170     MQTT      68
# 31464  207618  891.774869  130.185.238.170     192.168.15.8     MQTT      68
#
#        Source Port Message Identifier  Destination Port  \
# 0            58781                NaN              1883
# 1             1883                NaN             58781
# 2            58781                1,2              1883
# 3             1883                  1             58781
# 4             1883                  2             58781
# ...            ...                ...               ...
# 31460         1883                NaN             36773
# 31461        49543                NaN              1883
# 31462         1883                NaN             49543
# 31463        47351                NaN              1883
# 31464         1883                NaN             47351
#
#                                                     Info
# 0                                        Connect Command
# 1                                            Connect Ack
# 2      Subscribe Request (id=1) [devices-1], Publish ...
# 3                                   Subscribe Ack (id=1)
# 4        Publish Message [devices-1], Publish Ack (id=2)
# ...                                                  ...
# 31460                                      Ping Response
# 31461                                       Ping Request
# 31462                                      Ping Response
# 31463                                       Ping Request
# 31464                                      Ping Response
#
# [31465 rows x 10 columns]

# %%
#  - Separar publicações e confirmação de entrega por dispositivo simulado.
devices = {}
#  : devices será um dicionario que irá ter uma chave referente ao device e o valor será um dataframe referente aos respectivos devices 
for port in ports:  
  data = data.loc[ ~(data["Message Identifier"] == "1,2")]
  # data["Message Identifier"].dropna(replace=True)
  array_publish = data.loc[data["Source Port"] == port].dropna(subset=['Message Identifier'])
  array_publish_ack = data.loc[data["Destination Port"] == port].dropna(subset=['Message Identifier'])
  device = {"publish":array_publish, "publish_ack" : array_publish_ack}
  devices[port] = device

# %%
devicesNew = devices.copy()
for index in devices:
    if len(devices[index]["publish"]) <= 0:
        ports = ports.pop(index)

# %%
# - Criação de um dataframe com informações capturadas acima. 
data = {}
for port in ports:
    RTT = pd.DataFrame(columns=["Time_publish", "Time_ack"])
    for index, row in devices[port]["publish"].iterrows():
        id = int(row["Message Identifier"])
        time_publish = row["Time"]
        RTT.loc[id, "Time_publish"] = time_publish 

    for index, row in devices[port]["publish_ack"].iterrows():
        id = int(row["Message Identifier"])
        time_publish = row["Time"]
        RTT.loc[id, "Time_ack"] = time_publish
    RTT.loc[id, "Time_ack"] = time_publish
    RTT["RTT"]  =(RTT["Time_ack"] - RTT["Time_publish"] )* 1000
    data[port] = RTT

# %% [markdown]
# ## Medidas de Tendência Central Por Device

# %%
i=1
data_mean = []
data_median = []
data_std = []
data_min = []
data_max = []

for port in ports:
  data_mean.append(data[port]["RTT"].mean())
  data_median.append(data[port]["RTT"].mean())
  data_std.append(data[port]["RTT"].mean())
  data_min.append(data[port]["RTT"].mean())
  data_max.append(data[port]["RTT"].mean())

  print("(Device-{})Mean Round Trip Time = {}".format(i ,data[port]["RTT"].mean()))
  print("(Device-{})Median Round Trip Time = {}".format(i ,data[port]["RTT"].median()))
  print("(Device-{})Standard deviation  Round Trip Time = {}".format(i ,data[port]["RTT"].std()))
  print("(Device-{})Min Round Trip Time = {}".format(i ,data[port]["RTT"].min()))
  print("(Device-{})Max Round Trip Time = {}".format(i ,data[port]["RTT"].max()))
  print("---------------------------------------------------------------")

  i+=1
# Out:
# (Device-1)Mean Round Trip Time = 152.8437956130649
# (Device-1)Median Round Trip Time = 152.1387190000496
# (Device-1)Standard deviation  Round Trip Time = 6.308543635610815
# (Device-1)Min Round Trip Time = 149.80012700004863
# (Device-1)Max Round Trip Time = 232.15261600000758
# ---------------------------------------------------------------
# (Device-2)Mean Round Trip Time = 162.14559075879316
# (Device-2)Median Round Trip Time = 161.21795199990174
# (Device-2)Standard deviation  Round Trip Time = 6.355299823789699
# (Device-2)Min Round Trip Time = 158.3750739999914
# (Device-2)Max Round Trip Time = 212.52242799994292
# ---------------------------------------------------------------
# (Device-3)Mean Round Trip Time = 163.16587282914665
# (Device-3)Median Round Trip Time = 160.8280630000536
# (Device-3)Standard deviation  Round Trip Time = 18.231077206113675
# (Device-3)Min Round Trip Time = 158.05007799997384
# (Device-3)Max Round Trip Time = 388.1505599999855
# ---------------------------------------------------------------
# (Device-4)Mean Round Trip Time = 153.50585015075572
# (Device-4)Median Round Trip Time = 152.96226999998908
# (Device-4)Standard deviation  Round Trip Time = 5.079272046570867
# (Device-4)Min Round Trip Time = 150.6557149999992
# (Device-4)Max Round Trip Time = 213.34167000009074
# ---------------------------------------------------------------
# (Device-5)Mean Round Trip Time = 163.19386274874162
# (Device-5)Median Round Trip Time = 162.13970600000494
# (Device-5)Standard deviation  Round Trip Time = 5.969463184572565
# (Device-5)Min Round Trip Time = 152.32057399998666
# (Device-5)Max Round Trip Time = 219.47582200002103
# ---------------------------------------------------------------
# (Device-6)Mean Round Trip Time = 158.59824268844116
# (Device-6)Median Round Trip Time = 158.49793299997827
# (Device-6)Standard deviation  Round Trip Time = 21.42587220395966
# (Device-6)Min Round Trip Time = 149.99590000002172
# (Device-6)Max Round Trip Time = 446.3230229999908
# ---------------------------------------------------------------
# (Device-7)Mean Round Trip Time = 155.2023823618086
# (Device-7)Median Round Trip Time = 152.2102130000036
# (Device-7)Standard deviation  Round Trip Time = 27.401609166142382
# (Device-7)Min Round Trip Time = 149.04088299999785
# (Device-7)Max Round Trip Time = 455.1181649999876
# ---------------------------------------------------------------
# (Device-8)Mean Round Trip Time = 156.7101678944718
# (Device-8)Median Round Trip Time = 156.94416700000602
# (Device-8)Standard deviation  Round Trip Time = 5.048374143741394
# (Device-8)Min Round Trip Time = 150.16270300009182
# (Device-8)Max Round Trip Time = 186.8126850000067
# ---------------------------------------------------------------
# (Device-9)Mean Round Trip Time = 152.27156295477292
# (Device-9)Median Round Trip Time = 151.46185200001128
# (Device-9)Standard deviation  Round Trip Time = 4.866552506658767
# (Device-9)Min Round Trip Time = 149.10978099999284
# (Device-9)Max Round Trip Time = 197.02819000002592
# ---------------------------------------------------------------
# (Device-10)Mean Round Trip Time = 160.17566380402067
# (Device-10)Median Round Trip Time = 159.20025799999848
# (Device-10)Standard deviation  Round Trip Time = 7.778570974180271
# (Device-10)Min Round Trip Time = 149.84884199998305
# (Device-10)Max Round Trip Time = 242.2277440000009
# ---------------------------------------------------------------
# (Device-11)Mean Round Trip Time = 150.6376044020126
# (Device-11)Median Round Trip Time = 147.49950300006276
# (Device-11)Standard deviation  Round Trip Time = 20.971947458266687
# (Device-11)Min Round Trip Time = 142.21959200000356
# (Device-11)Max Round Trip Time = 435.0657840000167
# ---------------------------------------------------------------
# (Device-12)Mean Round Trip Time = 151.98462204522627
# (Device-12)Median Round Trip Time = 151.2162349999926
# (Device-12)Standard deviation  Round Trip Time = 5.140822223961408
# (Device-12)Min Round Trip Time = 149.04233100000397
# (Device-12)Max Round Trip Time = 196.268879999991
# ---------------------------------------------------------------
# (Device-13)Mean Round Trip Time = 160.44253540200896
# (Device-13)Median Round Trip Time = 158.33899500000825
# (Device-13)Standard deviation  Round Trip Time = 43.281636052010576
# (Device-13)Min Round Trip Time = 150.86872299991683
# (Device-13)Max Round Trip Time = 761.8557679999753
# ---------------------------------------------------------------
# (Device-14)Mean Round Trip Time = 153.1892469396987
# (Device-14)Median Round Trip Time = 152.3289570000088
# (Device-14)Standard deviation  Round Trip Time = 6.757526931320659
# (Device-14)Min Round Trip Time = 150.33405300005143
# (Device-14)Max Round Trip Time = 232.65187499998774
# ---------------------------------------------------------------
# (Device-15)Mean Round Trip Time = 151.6916279648233
# (Device-15)Median Round Trip Time = 151.45847200000162
# (Device-15)Standard deviation  Round Trip Time = 4.067366160652896
# (Device-15)Min Round Trip Time = 148.55808999999454
# (Device-15)Max Round Trip Time = 202.54934800004776
# ---------------------------------------------------------------
# (Device-16)Mean Round Trip Time = 161.6023417386918
# (Device-16)Median Round Trip Time = 160.5730030000032
# (Device-16)Standard deviation  Round Trip Time = 8.214547864720554
# (Device-16)Min Round Trip Time = 152.2989260000145
# (Device-16)Max Round Trip Time = 243.49466199998915
# ---------------------------------------------------------------
# (Device-17)Mean Round Trip Time = 153.35718620602472
# (Device-17)Median Round Trip Time = 152.88703999999598
# (Device-17)Standard deviation  Round Trip Time = 3.6404409044679475
# (Device-17)Min Round Trip Time = 146.5035809999904
# (Device-17)Max Round Trip Time = 195.70728700000473
# ---------------------------------------------------------------
# (Device-18)Mean Round Trip Time = 153.70078069849336
# (Device-18)Median Round Trip Time = 153.10272499999655
# (Device-18)Standard deviation  Round Trip Time = 4.250330831651342
# (Device-18)Min Round Trip Time = 150.65561200000843
# (Device-18)Max Round Trip Time = 195.94596799998953
# ---------------------------------------------------------------
# (Device-19)Mean Round Trip Time = 160.62679272864168
# (Device-19)Median Round Trip Time = 160.54733200000726
# (Device-19)Standard deviation  Round Trip Time = 2.895562815526103
# (Device-19)Min Round Trip Time = 151.4175379999756
# (Device-19)Max Round Trip Time = 187.89497100004837
# ---------------------------------------------------------------
# (Device-20)Mean Round Trip Time = 154.54618744723712
# (Device-20)Median Round Trip Time = 152.9342750000069
# (Device-20)Standard deviation  Round Trip Time = 14.726841687531781
# (Device-20)Min Round Trip Time = 150.43910000002825
# (Device-20)Max Round Trip Time = 354.98787500000617
# ---------------------------------------------------------------
# (Device-21)Mean Round Trip Time = 157.30383876382083
# (Device-21)Median Round Trip Time = 159.49292199999832
# (Device-21)Standard deviation  Round Trip Time = 5.114432293587841
# (Device-21)Min Round Trip Time = 150.41356000000405
# (Device-21)Max Round Trip Time = 186.23342300000445
# ---------------------------------------------------------------
# (Device-22)Mean Round Trip Time = 152.18363444221148
# (Device-22)Median Round Trip Time = 151.94743800003607
# (Device-22)Standard deviation  Round Trip Time = 1.5744677004442966
# (Device-22)Min Round Trip Time = 149.6320090000154
# (Device-22)Max Round Trip Time = 161.9794200000797
# ---------------------------------------------------------------
# (Device-23)Mean Round Trip Time = 153.29620029648072
# (Device-23)Median Round Trip Time = 151.1416410000379
# (Device-23)Standard deviation  Round Trip Time = 16.70850680418806
# (Device-23)Min Round Trip Time = 145.82206099998984
# (Device-23)Max Round Trip Time = 356.8850360001079
# ---------------------------------------------------------------
# (Device-24)Mean Round Trip Time = 157.22621586431893
# (Device-24)Median Round Trip Time = 154.0925279999783
# (Device-24)Standard deviation  Round Trip Time = 16.355296227109996
# (Device-24)Min Round Trip Time = 149.86087099998713
# (Device-24)Max Round Trip Time = 378.0991149999977
# ---------------------------------------------------------------
# (Device-25)Mean Round Trip Time = 161.65071278894456
# (Device-25)Median Round Trip Time = 161.12367300002006
# (Device-25)Standard deviation  Round Trip Time = 4.089848115421174
# (Device-25)Min Round Trip Time = 152.8187819999971
# (Device-25)Max Round Trip Time = 203.7790100000052
# ---------------------------------------------------------------
# (Device-26)Mean Round Trip Time = 154.05044873366964
# (Device-26)Median Round Trip Time = 152.97593000002507
# (Device-26)Standard deviation  Round Trip Time = 8.431160362473365
# (Device-26)Min Round Trip Time = 150.52704200002154
# (Device-26)Max Round Trip Time = 228.4152400000039
# ---------------------------------------------------------------
# (Device-27)Mean Round Trip Time = 152.4857351457271
# (Device-27)Median Round Trip Time = 151.61060299999463
# (Device-27)Standard deviation  Round Trip Time = 7.400665809797668
# (Device-27)Min Round Trip Time = 149.08674100001917
# (Device-27)Max Round Trip Time = 236.54528500000538
# ---------------------------------------------------------------
# (Device-28)Mean Round Trip Time = 159.10999151256217
# (Device-28)Median Round Trip Time = 159.0616799999225
# (Device-28)Standard deviation  Round Trip Time = 3.3482452769503204
# (Device-28)Min Round Trip Time = 150.1850839999861
# (Device-28)Max Round Trip Time = 198.96793700002036
# ---------------------------------------------------------------
# (Device-29)Mean Round Trip Time = 154.9202359798978
# (Device-29)Median Round Trip Time = 153.4964449999734
# (Device-29)Standard deviation  Round Trip Time = 9.33141486603841
# (Device-29)Min Round Trip Time = 150.42069699995864
# (Device-29)Max Round Trip Time = 248.8335009999787
# ---------------------------------------------------------------
# (Device-30)Mean Round Trip Time = 158.6711677738653
# (Device-30)Median Round Trip Time = 153.0783059999976
# (Device-30)Standard deviation  Round Trip Time = 47.88367511775588
# (Device-30)Min Round Trip Time = 150.36910900005296
# (Device-30)Max Round Trip Time = 748.2119690000104
# ---------------------------------------------------------------
# (Device-31)Mean Round Trip Time = 162.1552901306544
# (Device-31)Median Round Trip Time = 161.1659850000251
# (Device-31)Standard deviation  Round Trip Time = 7.269740888937203
# (Device-31)Min Round Trip Time = 158.57681600000717
# (Device-31)Max Round Trip Time = 227.01532100001032
# ---------------------------------------------------------------
# (Device-32)Mean Round Trip Time = 162.6871294170874
# (Device-32)Median Round Trip Time = 161.21176199999354
# (Device-32)Standard deviation  Round Trip Time = 8.222112618165625
# (Device-32)Min Round Trip Time = 158.6082919999967
# (Device-32)Max Round Trip Time = 221.65441399999963
# ---------------------------------------------------------------
# (Device-33)Mean Round Trip Time = 156.1287759145733
# (Device-33)Median Round Trip Time = 152.35783400004266
# (Device-33)Standard deviation  Round Trip Time = 10.714398138592184
# (Device-33)Min Round Trip Time = 146.75715100008802
# (Device-33)Max Round Trip Time = 247.25606000004063
# ---------------------------------------------------------------
# (Device-34)Mean Round Trip Time = 153.19890914070206
# (Device-34)Median Round Trip Time = 150.59321799998315
# (Device-34)Standard deviation  Round Trip Time = 18.82256129268999
# (Device-34)Min Round Trip Time = 145.13598600001387
# (Device-34)Max Round Trip Time = 387.7704939999944
# ---------------------------------------------------------------
# (Device-35)Mean Round Trip Time = 155.56237054271773
# (Device-35)Median Round Trip Time = 156.4576709999983
# (Device-35)Standard deviation  Round Trip Time = 7.519910334186569
# (Device-35)Min Round Trip Time = 148.02158399999144
# (Device-35)Max Round Trip Time = 229.45893800010708
# ---------------------------------------------------------------
# (Device-36)Mean Round Trip Time = 155.383689814074
# (Device-36)Median Round Trip Time = 153.51563000001534
# (Device-36)Standard deviation  Round Trip Time = 5.328601440469704
# (Device-36)Min Round Trip Time = 149.37788899999305
# (Device-36)Max Round Trip Time = 196.89073500001086
# ---------------------------------------------------------------
# (Device-37)Mean Round Trip Time = 156.36325584924484
# (Device-37)Median Round Trip Time = 153.34759299997813
# (Device-37)Standard deviation  Round Trip Time = 6.26672873689079
# (Device-37)Min Round Trip Time = 149.1667719999441
# (Device-37)Max Round Trip Time = 191.85084000000074
# ---------------------------------------------------------------
# (Device-38)Mean Round Trip Time = 147.47635225628048
# (Device-38)Median Round Trip Time = 145.3028560000007
# (Device-38)Standard deviation  Round Trip Time = 22.076946364103613
# (Device-38)Min Round Trip Time = 142.58991700000934
# (Device-38)Max Round Trip Time = 442.84461600000213
# ---------------------------------------------------------------
# (Device-39)Mean Round Trip Time = 153.09151601005053
# (Device-39)Median Round Trip Time = 152.42597200000318
# (Device-39)Standard deviation  Round Trip Time = 7.150622246146765
# (Device-39)Min Round Trip Time = 149.70916300001136
# (Device-39)Max Round Trip Time = 225.68026700000132
# ---------------------------------------------------------------
# (Device-40)Mean Round Trip Time = 151.54061162814256
# (Device-40)Median Round Trip Time = 150.9372969999987
# (Device-40)Standard deviation  Round Trip Time = 4.687309665266252
# (Device-40)Min Round Trip Time = 148.00801900000238
# (Device-40)Max Round Trip Time = 196.81236599996055
# ---------------------------------------------------------------
# (Device-41)Mean Round Trip Time = 159.63944215075077
# (Device-41)Median Round Trip Time = 159.1199790000246
# (Device-41)Standard deviation  Round Trip Time = 6.346180102702596
# (Device-41)Min Round Trip Time = 150.48237599995673
# (Device-41)Max Round Trip Time = 241.1598479999384
# ---------------------------------------------------------------
# (Device-42)Mean Round Trip Time = 153.07345454270802
# (Device-42)Median Round Trip Time = 152.79734999995753
# (Device-42)Standard deviation  Round Trip Time = 3.1500692107925636
# (Device-42)Min Round Trip Time = 150.31478599996717
# (Device-42)Max Round Trip Time = 183.79183900003682
# ---------------------------------------------------------------
# (Device-43)Mean Round Trip Time = 165.48975581407046
# (Device-43)Median Round Trip Time = 161.15354499999057
# (Device-43)Standard deviation  Round Trip Time = 42.27947932669759
# (Device-43)Min Round Trip Time = 158.05012900000293
# (Device-43)Max Round Trip Time = 752.414898999973
# ---------------------------------------------------------------
# (Device-44)Mean Round Trip Time = 151.53614455276528
# (Device-44)Median Round Trip Time = 151.1232469999868
# (Device-44)Standard deviation  Round Trip Time = 5.587738532674027
# (Device-44)Min Round Trip Time = 146.12664699996003
# (Device-44)Max Round Trip Time = 225.89585800000123
# ---------------------------------------------------------------
# (Device-45)Mean Round Trip Time = 151.43606800502542
# (Device-45)Median Round Trip Time = 150.72732299999814
# (Device-45)Standard deviation  Round Trip Time = 7.669928009842698
# (Device-45)Min Round Trip Time = 145.73774400003003
# (Device-45)Max Round Trip Time = 237.20150299999432
# ---------------------------------------------------------------
# (Device-46)Mean Round Trip Time = 151.7129650402048
# (Device-46)Median Round Trip Time = 151.55860000004395
# (Device-46)Standard deviation  Round Trip Time = 20.114667208621505
# (Device-46)Min Round Trip Time = 143.19089399998575
# (Device-46)Max Round Trip Time = 423.68693299999904
# ---------------------------------------------------------------
# (Device-47)Mean Round Trip Time = 155.64947538693607
# (Device-47)Median Round Trip Time = 152.63829600002055
# (Device-47)Standard deviation  Round Trip Time = 7.773928433597551
# (Device-47)Min Round Trip Time = 146.82429999999158
# (Device-47)Max Round Trip Time = 228.39279799995893
# ---------------------------------------------------------------
# (Device-48)Mean Round Trip Time = 154.58940054774146
# (Device-48)Median Round Trip Time = 152.3563309999929
# (Device-48)Standard deviation  Round Trip Time = 17.493772720267433
# (Device-48)Min Round Trip Time = 150.17895999994835
# (Device-48)Max Round Trip Time = 377.76247499999727
# ---------------------------------------------------------------
# (Device-49)Mean Round Trip Time = 151.85206028643327
# (Device-49)Median Round Trip Time = 150.92651900002352
# (Device-49)Standard deviation  Round Trip Time = 7.111761620161067
# (Device-49)Min Round Trip Time = 146.7638050000346
# (Device-49)Max Round Trip Time = 215.49175799998466
# ---------------------------------------------------------------
# (Device-50)Mean Round Trip Time = 153.86793524622877
# (Device-50)Median Round Trip Time = 152.94877499997028
# (Device-50)Standard deviation  Round Trip Time = 7.776222963264276
# (Device-50)Min Round Trip Time = 150.4460480000489
# (Device-50)Max Round Trip Time = 231.17808400002104
# ---------------------------------------------------------------

# %% [markdown]
# # CÁLCULO DO TAMANHO DA AMOSTRA

# %%
nivel_de_significancia = 0.05

# %%
nivel_de_confiança = 1 - nivel_de_significancia
nivel_de_confiança
# Out:
# 0.95

# %%
#Calculando o z com scipy
z = scipy.stats.norm.ppf(0.975)
z
# Out:
# 1.959963984540054

# %% [markdown]
# Com nosso z calculado podemos seguir adiante
#
# ### $$z = 1.959963984540054 $$
#
# Abaixo segue algumas formulas que iremos utilizar para calcular o numero de amostra

# %% [markdown]
# ### Calculando o tamanho da nossa amostra

# %%
df_concatenado = pd.concat(data.values())
desvio_padrao_amostral = df_concatenado["RTT"].std()
media = df_concatenado["RTT"].mean()
e = 0.05 * media
n = (z * ( desvio_padrao_amostral/e) )**2
n
# Out:
# 15.796918961649673

# %%
e = df_concatenado["RTT"].mean() * 0.05

# %%
desvio_padrao_amostral
# Out:
# 15.80296520892524

# %%
import matplotlib 
i=1
fig, ax = plt.subplots(figsize=(10,5),dpi=72)
for port in ports:
  ax.scatter(data[port]["RTT"].index,data[port]["RTT"], label='Dispositivo-{}'.format(i))
  ax.set_ylabel('Round Trip Time (ms)')
  ax.set_xlabel('Quantidade de Publicação')
  ax.set_title('Gráfico de dispersão (Round Trip Time)')
#   ax.hlines(data[port]["RTT"].max(),  xmin=0, xmax=620, colors="red", linestyles="dashed", label="Maior Medição")
#   ax.hlines(data[port]["RTT"].min(),  xmin=0, xmax=620, colors="green", linestyles="dashed", label="Menor Medição")
  ax.legend()
  i+=1
