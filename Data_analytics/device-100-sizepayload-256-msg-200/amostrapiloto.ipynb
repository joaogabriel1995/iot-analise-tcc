# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import scipy
import numpy as np
import seaborn as sns

# %% [markdown]
# Objetivos do Script:
#
# Esse script tem como objetivo ler os dados que foram capturados da nossa amostra piloto e realizar alguns estudos em cima desses dados.
#
# Os 6 primeiros tópicos que eu separei abaixo são utilizados na grande maioria dos scripts de tratamento de dados desse estudo.
# Deixei padronizado para que seja possivel tratar simulações com um dispositivo ou vários.
#
# Sumário:
#   - Leitura dos dados
#   - Separar publicações e confirmação de entrega por dispositivo simulado.
#   - Criação de um dataframe com informações capturadas.
#   - Medidas de tendência centrar por dispositivo
#   - Medidas de tendência centrar de todos os dispositivos.
#   - Gráfico de dispersão da amostra.
#   - Calculo do tamanho da amostra.
#
# Como estamos trabalhando com uma amostra piloto temos como objetivo calcular o tamanho das amostras isso será realizado na ultima parte desse script.

# %%
data = pd.read_csv("./data2.csv", encoding="latin")
ports = data["Source Port"].unique()
ports = ports[ports !=1883]

# %%
#  - Separar publicações e confirmação de entrega por dispositivo simulado.
devices = {}
#  : devices será um dicionario que irá ter uma chave referente ao device e o valor será um dataframe referente aos respectivos devices 
for port in ports:  
  data = data.loc[ ~(data["Message Identifier"] == "1,2")]
  # data["Message Identifier"].dropna(replace=True)
  array_publish = data.loc[data["Source Port"] == port].dropna(subset=['Message Identifier'])
  array_publish_ack = data.loc[data["Destination Port"] == port].dropna(subset=['Message Identifier'])
  device = {"publish":array_publish, "publish_ack" : array_publish_ack}
  devices[port] = device

# %%
devicesNew = devices.copy()
for index in devices:
    if len(devices[index]["publish"]) <= 0:
        ports = ports[ports !=index]

# %%
# - Criação de um dataframe com informações capturadas acima. 
data = {}
for port in ports:
    RTT = pd.DataFrame(columns=["Time_publish", "Time_ack"])
    for index, row in devices[port]["publish"].iterrows():
        id = int(row["Message Identifier"])
        time_publish = row["Time"]
        RTT.loc[id, "Time_publish"] = time_publish 

    for index, row in devices[port]["publish_ack"].iterrows():
        id = int(row["Message Identifier"])
        time_publish = row["Time"]
        RTT.loc[id, "Time_ack"] = time_publish
    RTT.loc[id, "Time_ack"] = time_publish
    RTT["RTT"]  =(RTT["Time_ack"] - RTT["Time_publish"] )* 1000
    data[port] = RTT[1:]

# %%
for port in ports:
    print(data[port].shape[0] != 199)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# ## Medidas de Tendência Central Por Device

# %%
i=1
data_mean = []
data_median = []
data_std = []
data_min = []
data_max = []

for port in ports:
  data_mean.append(data[port]["RTT"].mean())
  data_median.append(data[port]["RTT"].mean())
  data_std.append(data[port]["RTT"].mean())
  data_min.append(data[port]["RTT"].mean())
  data_max.append(data[port]["RTT"].mean())

  print("(Device-{})Mean Round Trip Time = {}".format(i ,data[port]["RTT"].mean()))
  print("(Device-{})Median Round Trip Time = {}".format(i ,data[port]["RTT"].median()))
  print("(Device-{})Standard deviation  Round Trip Time = {}".format(i ,data[port]["RTT"].std()))
  print("(Device-{})Min Round Trip Time = {}".format(i ,data[port]["RTT"].min()))
  print("(Device-{})Max Round Trip Time = {}".format(i ,data[port]["RTT"].max()))
  print("---------------------------------------------------------------")

  i+=1
# Out:
# (Device-1)Mean Round Trip Time = 22.809371502514804
# (Device-1)Median Round Trip Time = 22.901885000010225
# (Device-1)Standard deviation  Round Trip Time = 1.1733300712578847
# (Device-1)Min Round Trip Time = 20.654201000013472
# (Device-1)Max Round Trip Time = 25.21347700002252
# ---------------------------------------------------------------
# (Device-2)Mean Round Trip Time = 23.752115346734204
# (Device-2)Median Round Trip Time = 23.505850999981703
# (Device-2)Standard deviation  Round Trip Time = 3.0377060338441795
# (Device-2)Min Round Trip Time = 21.449894999989283
# (Device-2)Max Round Trip Time = 62.88499499999034
# ---------------------------------------------------------------
# (Device-3)Mean Round Trip Time = 22.672966251252134
# (Device-3)Median Round Trip Time = 22.654847000012523
# (Device-3)Standard deviation  Round Trip Time = 1.243122045535492
# (Device-3)Min Round Trip Time = 20.609688000000403
# (Device-3)Max Round Trip Time = 24.90360699999883
# ---------------------------------------------------------------
# (Device-4)Mean Round Trip Time = 23.667825698490546
# (Device-4)Median Round Trip Time = 23.305434999997487
# (Device-4)Standard deviation  Round Trip Time = 3.2277997142538015
# (Device-4)Min Round Trip Time = 21.51776499999869
# (Device-4)Max Round Trip Time = 65.72855400008848
# ---------------------------------------------------------------
# (Device-5)Mean Round Trip Time = 22.597955698493482
# (Device-5)Median Round Trip Time = 22.59610999999495
# (Device-5)Standard deviation  Round Trip Time = 1.147554139313974
# (Device-5)Min Round Trip Time = 20.44683500000133
# (Device-5)Max Round Trip Time = 25.110075000043253
# ---------------------------------------------------------------
# (Device-6)Mean Round Trip Time = 22.682100904527196
# (Device-6)Median Round Trip Time = 22.704738000015823
# (Device-6)Standard deviation  Round Trip Time = 1.4088095503271012
# (Device-6)Min Round Trip Time = 12.150646999998571
# (Device-6)Max Round Trip Time = 24.906036000004406
# ---------------------------------------------------------------
# (Device-7)Mean Round Trip Time = 22.989884391960548
# (Device-7)Median Round Trip Time = 23.162614999989728
# (Device-7)Standard deviation  Round Trip Time = 1.175143076745716
# (Device-7)Min Round Trip Time = 20.544033999982503
# (Device-7)Max Round Trip Time = 25.463168999991126
# ---------------------------------------------------------------
# (Device-8)Mean Round Trip Time = 22.759478482411375
# (Device-8)Median Round Trip Time = 22.687305000005153
# (Device-8)Standard deviation  Round Trip Time = 1.1579830035637149
# (Device-8)Min Round Trip Time = 20.605564999982562
# (Device-8)Max Round Trip Time = 24.873318000004474
# ---------------------------------------------------------------
# (Device-9)Mean Round Trip Time = 22.928300743715834
# (Device-9)Median Round Trip Time = 22.81856899998047
# (Device-9)Standard deviation  Round Trip Time = 3.1153292288325596
# (Device-9)Min Round Trip Time = 20.471107000005873
# (Device-9)Max Round Trip Time = 63.78796700005296
# ---------------------------------------------------------------
# (Device-10)Mean Round Trip Time = 23.185675748746227
# (Device-10)Median Round Trip Time = 22.705314000006638
# (Device-10)Standard deviation  Round Trip Time = 4.541626700537429
# (Device-10)Min Round Trip Time = 20.745871999992005
# (Device-10)Max Round Trip Time = 68.25194900000042
# ---------------------------------------------------------------
# (Device-11)Mean Round Trip Time = 22.73815662311343
# (Device-11)Median Round Trip Time = 22.679396999933488
# (Device-11)Standard deviation  Round Trip Time = 1.1512719053924656
# (Device-11)Min Round Trip Time = 20.710562999965987
# (Device-11)Max Round Trip Time = 24.96190699997669
# ---------------------------------------------------------------
# (Device-12)Mean Round Trip Time = 22.698661341712658
# (Device-12)Median Round Trip Time = 22.756503999971756
# (Device-12)Standard deviation  Round Trip Time = 1.142550295554561
# (Device-12)Min Round Trip Time = 20.465545999996948
# (Device-12)Max Round Trip Time = 24.758289999994076
# ---------------------------------------------------------------
# (Device-13)Mean Round Trip Time = 22.686110683417805
# (Device-13)Median Round Trip Time = 22.66238599997905
# (Device-13)Standard deviation  Round Trip Time = 1.2086723867831617
# (Device-13)Min Round Trip Time = 20.627331000014237
# (Device-13)Max Round Trip Time = 25.94609200002651
# ---------------------------------------------------------------
# (Device-14)Mean Round Trip Time = 23.233939391958394
# (Device-14)Median Round Trip Time = 23.38006000002224
# (Device-14)Standard deviation  Round Trip Time = 1.15981751902088
# (Device-14)Min Round Trip Time = 20.81181799999854
# (Device-14)Max Round Trip Time = 25.27342300000157
# ---------------------------------------------------------------
# (Device-15)Mean Round Trip Time = 22.881969316582467
# (Device-15)Median Round Trip Time = 22.80786200003604
# (Device-15)Standard deviation  Round Trip Time = 1.215948725193479
# (Device-15)Min Round Trip Time = 20.509506999928817
# (Device-15)Max Round Trip Time = 25.356973999976162
# ---------------------------------------------------------------
# (Device-16)Mean Round Trip Time = 23.648895266331376
# (Device-16)Median Round Trip Time = 23.639615999996977
# (Device-16)Standard deviation  Round Trip Time = 1.1200720135500855
# (Device-16)Min Round Trip Time = 21.328431000029013
# (Device-16)Max Round Trip Time = 25.557367999994085
# ---------------------------------------------------------------
# (Device-17)Mean Round Trip Time = 23.615538035174605
# (Device-17)Median Round Trip Time = 23.56770000000097
# (Device-17)Standard deviation  Round Trip Time = 1.1216811772339073
# (Device-17)Min Round Trip Time = 21.47008599996525
# (Device-17)Max Round Trip Time = 25.69163399999752
# ---------------------------------------------------------------
# (Device-18)Mean Round Trip Time = 23.205842381912767
# (Device-18)Median Round Trip Time = 22.930078000001686
# (Device-18)Standard deviation  Round Trip Time = 4.35708780021226
# (Device-18)Min Round Trip Time = 20.4895580000084
# (Device-18)Max Round Trip Time = 66.66954400009217
# ---------------------------------------------------------------
# (Device-19)Mean Round Trip Time = 23.71785039196112
# (Device-19)Median Round Trip Time = 23.410670999965077
# (Device-19)Standard deviation  Round Trip Time = 3.1092459856847547
# (Device-19)Min Round Trip Time = 21.16035799997462
# (Device-19)Max Round Trip Time = 63.862026000037986
# ---------------------------------------------------------------
# (Device-20)Mean Round Trip Time = 22.594660899498493
# (Device-20)Median Round Trip Time = 22.610774000042966
# (Device-20)Standard deviation  Round Trip Time = 1.1638873262709164
# (Device-20)Min Round Trip Time = 20.450667999966754
# (Device-20)Max Round Trip Time = 24.651005000009718
# ---------------------------------------------------------------
# (Device-21)Mean Round Trip Time = 22.968976040203977
# (Device-21)Median Round Trip Time = 23.11591700004101
# (Device-21)Standard deviation  Round Trip Time = 1.2112466264459958
# (Device-21)Min Round Trip Time = 20.536256000013964
# (Device-21)Max Round Trip Time = 25.790921999998773
# ---------------------------------------------------------------
# (Device-22)Mean Round Trip Time = 23.199199115577883
# (Device-22)Median Round Trip Time = 23.292202000007478
# (Device-22)Standard deviation  Round Trip Time = 1.171604631219462
# (Device-22)Min Round Trip Time = 20.981845999997972
# (Device-22)Max Round Trip Time = 28.126366999913444
# ---------------------------------------------------------------
# (Device-23)Mean Round Trip Time = 22.628105306536053
# (Device-23)Median Round Trip Time = 22.607955000012225
# (Device-23)Standard deviation  Round Trip Time = 1.2059232474448398
# (Device-23)Min Round Trip Time = 20.583407000003717
# (Device-23)Max Round Trip Time = 24.84306900001343
# ---------------------------------------------------------------
# (Device-24)Mean Round Trip Time = 22.781801391962578
# (Device-24)Median Round Trip Time = 22.75420800003758
# (Device-24)Standard deviation  Round Trip Time = 1.114287424879342
# (Device-24)Min Round Trip Time = 20.859813000015492
# (Device-24)Max Round Trip Time = 24.984786999993958
# ---------------------------------------------------------------
# (Device-25)Mean Round Trip Time = 23.610227824117313
# (Device-25)Median Round Trip Time = 23.50806399999783
# (Device-25)Standard deviation  Round Trip Time = 1.1651222552571778
# (Device-25)Min Round Trip Time = 21.42141900000638
# (Device-25)Max Round Trip Time = 25.653056999999535
# ---------------------------------------------------------------
# (Device-26)Mean Round Trip Time = 23.888542120602207
# (Device-26)Median Round Trip Time = 23.716917999990983
# (Device-26)Standard deviation  Round Trip Time = 3.051810955158411
# (Device-26)Min Round Trip Time = 21.56838100000158
# (Device-26)Max Round Trip Time = 64.01443500000426
# ---------------------------------------------------------------
# (Device-27)Mean Round Trip Time = 23.967887743716933
# (Device-27)Median Round Trip Time = 23.763094000059937
# (Device-27)Standard deviation  Round Trip Time = 3.5998040272574383
# (Device-27)Min Round Trip Time = 21.42584899996791
# (Device-27)Max Round Trip Time = 71.91333299999769
# ---------------------------------------------------------------
# (Device-28)Mean Round Trip Time = 22.94366133668159
# (Device-28)Median Round Trip Time = 23.017039000023942
# (Device-28)Standard deviation  Round Trip Time = 1.1792899303871054
# (Device-28)Min Round Trip Time = 20.532602000002953
# (Device-28)Max Round Trip Time = 28.339310999996314
# ---------------------------------------------------------------
# (Device-29)Mean Round Trip Time = 22.55980382411704
# (Device-29)Median Round Trip Time = 22.548188999991226
# (Device-29)Standard deviation  Round Trip Time = 1.1059598547425558
# (Device-29)Min Round Trip Time = 20.657429999999977
# (Device-29)Max Round Trip Time = 24.64601799999855
# ---------------------------------------------------------------
# (Device-30)Mean Round Trip Time = 23.68808190954988
# (Device-30)Median Round Trip Time = 23.75701199997593
# (Device-30)Standard deviation  Round Trip Time = 1.1798357228358562
# (Device-30)Min Round Trip Time = 21.447259999945345
# (Device-30)Max Round Trip Time = 25.652430000008053
# ---------------------------------------------------------------
# (Device-31)Mean Round Trip Time = 22.982978587941687
# (Device-31)Median Round Trip Time = 23.144812999987607
# (Device-31)Standard deviation  Round Trip Time = 1.1350609411290764
# (Device-31)Min Round Trip Time = 20.663050999985444
# (Device-31)Max Round Trip Time = 25.055319000017562
# ---------------------------------------------------------------
# (Device-32)Mean Round Trip Time = 23.831304653263814
# (Device-32)Median Round Trip Time = 23.885320999966098
# (Device-32)Standard deviation  Round Trip Time = 1.2174816886452766
# (Device-32)Min Round Trip Time = 21.479286000001707
# (Device-32)Max Round Trip Time = 25.76358800001799
# ---------------------------------------------------------------
# (Device-33)Mean Round Trip Time = 23.74431221105559
# (Device-33)Median Round Trip Time = 23.817111999989038
# (Device-33)Standard deviation  Round Trip Time = 1.1624811632594907
# (Device-33)Min Round Trip Time = 21.508910999955333
# (Device-33)Max Round Trip Time = 27.361073000008673
# ---------------------------------------------------------------
# (Device-34)Mean Round Trip Time = 22.710974793967193
# (Device-34)Median Round Trip Time = 22.738256000025103
# (Device-34)Standard deviation  Round Trip Time = 1.1315668762269777
# (Device-34)Min Round Trip Time = 20.57794200004537
# (Device-34)Max Round Trip Time = 24.900365000007696
# ---------------------------------------------------------------
# (Device-35)Mean Round Trip Time = 23.26862602009683
# (Device-35)Median Round Trip Time = 23.333995999962553
# (Device-35)Standard deviation  Round Trip Time = 1.1346294505103767
# (Device-35)Min Round Trip Time = 21.27694299997529
# (Device-35)Max Round Trip Time = 25.099582999928316
# ---------------------------------------------------------------
# (Device-36)Mean Round Trip Time = 23.157892000002043
# (Device-36)Median Round Trip Time = 23.28917700000943
# (Device-36)Standard deviation  Round Trip Time = 1.159699678871014
# (Device-36)Min Round Trip Time = 20.885170000042308
# (Device-36)Max Round Trip Time = 25.337299000000257
# ---------------------------------------------------------------
# (Device-37)Mean Round Trip Time = 23.182394417086247
# (Device-37)Median Round Trip Time = 23.156101000040508
# (Device-37)Standard deviation  Round Trip Time = 1.1465052229973058
# (Device-37)Min Round Trip Time = 21.13941300001443
# (Device-37)Max Round Trip Time = 25.32265299998926
# ---------------------------------------------------------------
# (Device-38)Mean Round Trip Time = 23.106597824119007
# (Device-38)Median Round Trip Time = 23.027307999996083
# (Device-38)Standard deviation  Round Trip Time = 1.1464363705410754
# (Device-38)Min Round Trip Time = 21.232815000004734
# (Device-38)Max Round Trip Time = 25.32422900000597
# ---------------------------------------------------------------
# (Device-39)Mean Round Trip Time = 22.973984095476382
# (Device-39)Median Round Trip Time = 22.998697999923934
# (Device-39)Standard deviation  Round Trip Time = 1.057453373599502
# (Device-39)Min Round Trip Time = 20.78460500001711
# (Device-39)Max Round Trip Time = 24.850076999996418
# ---------------------------------------------------------------
# (Device-40)Mean Round Trip Time = 23.617378231154813
# (Device-40)Median Round Trip Time = 23.252013000004013
# (Device-40)Standard deviation  Round Trip Time = 4.377483245237499
# (Device-40)Min Round Trip Time = 21.18646900009935
# (Device-40)Max Round Trip Time = 67.67032400000517
# ---------------------------------------------------------------
# (Device-41)Mean Round Trip Time = 22.636018241202695
# (Device-41)Median Round Trip Time = 22.55977999999459
# (Device-41)Standard deviation  Round Trip Time = 1.2361416510635652
# (Device-41)Min Round Trip Time = 20.366382999952748
# (Device-41)Max Round Trip Time = 25.912466000022505
# ---------------------------------------------------------------
# (Device-42)Mean Round Trip Time = 23.189198120605784
# (Device-42)Median Round Trip Time = 23.162503000008883
# (Device-42)Standard deviation  Round Trip Time = 1.1468467963761193
# (Device-42)Min Round Trip Time = 21.018189000017173
# (Device-42)Max Round Trip Time = 25.326995000000352
# ---------------------------------------------------------------
# (Device-43)Mean Round Trip Time = 22.844843281407574
# (Device-43)Median Round Trip Time = 22.94074899998577
# (Device-43)Standard deviation  Round Trip Time = 1.1961832998540796
# (Device-43)Min Round Trip Time = 20.47277999997732
# (Device-43)Max Round Trip Time = 25.03124600002593
# ---------------------------------------------------------------
# (Device-44)Mean Round Trip Time = 22.82807711055584
# (Device-44)Median Round Trip Time = 22.675061000029473
# (Device-44)Standard deviation  Round Trip Time = 3.1308320404629613
# (Device-44)Min Round Trip Time = 20.388149999973848
# (Device-44)Max Round Trip Time = 63.68307499997172
# ---------------------------------------------------------------
# (Device-45)Mean Round Trip Time = 23.11286317085609
# (Device-45)Median Round Trip Time = 22.95365899999524
# (Device-45)Standard deviation  Round Trip Time = 1.1854914988760838
# (Device-45)Min Round Trip Time = 20.669807000004425
# (Device-45)Max Round Trip Time = 25.20245200000204
# ---------------------------------------------------------------
# (Device-46)Mean Round Trip Time = 23.605502783919817
# (Device-46)Median Round Trip Time = 23.67356799999243
# (Device-46)Standard deviation  Round Trip Time = 1.1881665510697361
# (Device-46)Min Round Trip Time = 21.162665000019842
# (Device-46)Max Round Trip Time = 26.388106000013067
# ---------------------------------------------------------------
# (Device-47)Mean Round Trip Time = 23.2041834723614
# (Device-47)Median Round Trip Time = 22.795266000002812
# (Device-47)Standard deviation  Round Trip Time = 4.229876232264405
# (Device-47)Min Round Trip Time = 20.495643000003838
# (Device-47)Max Round Trip Time = 65.85905500003264
# ---------------------------------------------------------------
# (Device-48)Mean Round Trip Time = 22.753321899496136
# (Device-48)Median Round Trip Time = 22.833695000031184
# (Device-48)Standard deviation  Round Trip Time = 1.200447414508679
# (Device-48)Min Round Trip Time = 18.916476999947918
# (Device-48)Max Round Trip Time = 24.848292000001493
# ---------------------------------------------------------------
# (Device-49)Mean Round Trip Time = 23.345789713565882
# (Device-49)Median Round Trip Time = 23.15750599996136
# (Device-49)Standard deviation  Round Trip Time = 3.1805105431255973
# (Device-49)Min Round Trip Time = 20.8872850000148
# (Device-49)Max Round Trip Time = 64.93236400001479
# ---------------------------------------------------------------
# (Device-50)Mean Round Trip Time = 23.588811603014193
# (Device-50)Median Round Trip Time = 23.479621000035422
# (Device-50)Standard deviation  Round Trip Time = 3.212713536210525
# (Device-50)Min Round Trip Time = 21.310753999998155
# (Device-50)Max Round Trip Time = 65.97250900000518
# ---------------------------------------------------------------
# (Device-51)Mean Round Trip Time = 23.329847211055128
# (Device-51)Median Round Trip Time = 23.454660999959742
# (Device-51)Standard deviation  Round Trip Time = 1.2810555036227356
# (Device-51)Min Round Trip Time = 20.614733999991586
# (Device-51)Max Round Trip Time = 29.083409999998366
# ---------------------------------------------------------------
# (Device-52)Mean Round Trip Time = 23.409127567839725
# (Device-52)Median Round Trip Time = 23.31271499997456
# (Device-52)Standard deviation  Round Trip Time = 3.120571329430742
# (Device-52)Min Round Trip Time = 21.03460199998608
# (Device-52)Max Round Trip Time = 63.87863399999105
# ---------------------------------------------------------------
# (Device-53)Mean Round Trip Time = 22.741663170854736
# (Device-53)Median Round Trip Time = 22.653676000004452
# (Device-53)Standard deviation  Round Trip Time = 1.1998814270371225
# (Device-53)Min Round Trip Time = 20.518950999999674
# (Device-53)Max Round Trip Time = 25.099995999994462
# ---------------------------------------------------------------
# (Device-54)Mean Round Trip Time = 22.76321578894087
# (Device-54)Median Round Trip Time = 22.74843800000781
# (Device-54)Standard deviation  Round Trip Time = 1.1535934526491887
# (Device-54)Min Round Trip Time = 20.57996500002446
# (Device-54)Max Round Trip Time = 24.822288999985176
# ---------------------------------------------------------------
# (Device-55)Mean Round Trip Time = 23.120741728637725
# (Device-55)Median Round Trip Time = 23.152331999995113
# (Device-55)Standard deviation  Round Trip Time = 1.1918898941686404
# (Device-55)Min Round Trip Time = 20.973662000017157
# (Device-55)Max Round Trip Time = 25.107155999990027
# ---------------------------------------------------------------
# (Device-56)Mean Round Trip Time = 22.72142522612641
# (Device-56)Median Round Trip Time = 22.617846000002828
# (Device-56)Standard deviation  Round Trip Time = 1.1085633368762144
# (Device-56)Min Round Trip Time = 20.765908999990756
# (Device-56)Max Round Trip Time = 24.859138000010716
# ---------------------------------------------------------------
# (Device-57)Mean Round Trip Time = 22.841155854270728
# (Device-57)Median Round Trip Time = 23.04386800000202
# (Device-57)Standard deviation  Round Trip Time = 1.182983819651804
# (Device-57)Min Round Trip Time = 20.642126999973698
# (Device-57)Max Round Trip Time = 24.78986400001304
# ---------------------------------------------------------------
# (Device-58)Mean Round Trip Time = 22.974822733668546
# (Device-58)Median Round Trip Time = 22.693488000001594
# (Device-58)Standard deviation  Round Trip Time = 2.9331307614850446
# (Device-58)Min Round Trip Time = 20.705970999998158
# (Device-58)Max Round Trip Time = 60.83579999994981
# ---------------------------------------------------------------
# (Device-59)Mean Round Trip Time = 22.874907180905772
# (Device-59)Median Round Trip Time = 22.6431070000217
# (Device-59)Standard deviation  Round Trip Time = 3.4341910002449656
# (Device-59)Min Round Trip Time = 20.572224999966693
# (Device-59)Max Round Trip Time = 67.91255699999965
# ---------------------------------------------------------------
# (Device-60)Mean Round Trip Time = 22.996270658288573
# (Device-60)Median Round Trip Time = 22.82751900000335
# (Device-60)Standard deviation  Round Trip Time = 2.9864429830827772
# (Device-60)Min Round Trip Time = 20.189347999917118
# (Device-60)Max Round Trip Time = 61.777879000032954
# ---------------------------------------------------------------
# (Device-61)Mean Round Trip Time = 22.790695085424233
# (Device-61)Median Round Trip Time = 22.798839000074622
# (Device-61)Standard deviation  Round Trip Time = 1.1381516558907367
# (Device-61)Min Round Trip Time = 20.72336699995958
# (Device-61)Max Round Trip Time = 24.77894999998398
# ---------------------------------------------------------------
# (Device-62)Mean Round Trip Time = 23.657566241205465
# (Device-62)Median Round Trip Time = 23.59144800004742
# (Device-62)Standard deviation  Round Trip Time = 1.2136113199621368
# (Device-62)Min Round Trip Time = 21.185250000030464
# (Device-62)Max Round Trip Time = 25.792475999992348
# ---------------------------------------------------------------
# (Device-63)Mean Round Trip Time = 22.778498065328456
# (Device-63)Median Round Trip Time = 22.63992700000017
# (Device-63)Standard deviation  Round Trip Time = 1.142892206348924
# (Device-63)Min Round Trip Time = 20.722037000041382
# (Device-63)Max Round Trip Time = 25.531879000027402
# ---------------------------------------------------------------
# (Device-64)Mean Round Trip Time = 22.851278934673793
# (Device-64)Median Round Trip Time = 22.83244900002046
# (Device-64)Standard deviation  Round Trip Time = 1.123228422068361
# (Device-64)Min Round Trip Time = 20.581265000032545
# (Device-64)Max Round Trip Time = 24.83524199999465
# ---------------------------------------------------------------
# (Device-65)Mean Round Trip Time = 22.789644316583455
# (Device-65)Median Round Trip Time = 22.790745000065726
# (Device-65)Standard deviation  Round Trip Time = 1.1629638577954071
# (Device-65)Min Round Trip Time = 20.594370999958755
# (Device-65)Max Round Trip Time = 24.826207000046452
# ---------------------------------------------------------------
# (Device-66)Mean Round Trip Time = 23.166502070346123
# (Device-66)Median Round Trip Time = 23.193960999947194
# (Device-66)Standard deviation  Round Trip Time = 1.253371987777099
# (Device-66)Min Round Trip Time = 21.117305000018405
# (Device-66)Max Round Trip Time = 25.33096799999157
# ---------------------------------------------------------------
# (Device-67)Mean Round Trip Time = 23.412864678391077
# (Device-67)Median Round Trip Time = 23.289236999971763
# (Device-67)Standard deviation  Round Trip Time = 2.9848535913128758
# (Device-67)Min Round Trip Time = 21.048496999981126
# (Device-67)Max Round Trip Time = 62.191584999993665
# ---------------------------------------------------------------
# (Device-68)Mean Round Trip Time = 22.885220452262175
# (Device-68)Median Round Trip Time = 22.908862000008412
# (Device-68)Standard deviation  Round Trip Time = 1.414439099149215
# (Device-68)Min Round Trip Time = 20.49487399997929
# (Device-68)Max Round Trip Time = 34.55093700000589
# ---------------------------------------------------------------
# (Device-69)Mean Round Trip Time = 23.283971452264105
# (Device-69)Median Round Trip Time = 22.995123000043804
# (Device-69)Standard deviation  Round Trip Time = 3.2082358736018204
# (Device-69)Min Round Trip Time = 20.936234999908265
# (Device-69)Max Round Trip Time = 65.03169899997374
# ---------------------------------------------------------------
# (Device-70)Mean Round Trip Time = 23.562190010046248
# (Device-70)Median Round Trip Time = 23.62551999999596
# (Device-70)Standard deviation  Round Trip Time = 1.116375178265377
# (Device-70)Min Round Trip Time = 21.525965999956043
# (Device-70)Max Round Trip Time = 25.55680900002244
# ---------------------------------------------------------------
# (Device-71)Mean Round Trip Time = 23.157521874369973
# (Device-71)Median Round Trip Time = 23.207498999994414
# (Device-71)Standard deviation  Round Trip Time = 1.1996469069230016
# (Device-71)Min Round Trip Time = 20.758610999905613
# (Device-71)Max Round Trip Time = 25.28777899999568
# ---------------------------------------------------------------
# (Device-72)Mean Round Trip Time = 23.204176236183283
# (Device-72)Median Round Trip Time = 23.212637000028735
# (Device-72)Standard deviation  Round Trip Time = 1.1313452393598329
# (Device-72)Min Round Trip Time = 21.16212000004225
# (Device-72)Max Round Trip Time = 25.28006899990487
# ---------------------------------------------------------------
# (Device-73)Mean Round Trip Time = 23.62502882411934
# (Device-73)Median Round Trip Time = 23.715842999990855
# (Device-73)Standard deviation  Round Trip Time = 1.257102493148797
# (Device-73)Min Round Trip Time = 21.47199200000216
# (Device-73)Max Round Trip Time = 29.104993999993667
# ---------------------------------------------------------------
# (Device-74)Mean Round Trip Time = 23.085134793968628
# (Device-74)Median Round Trip Time = 22.861121999994793
# (Device-74)Standard deviation  Round Trip Time = 3.3900531845905624
# (Device-74)Min Round Trip Time = 20.498825000004217
# (Device-74)Max Round Trip Time = 67.79497000002266
# ---------------------------------------------------------------
# (Device-75)Mean Round Trip Time = 23.627160125628784
# (Device-75)Median Round Trip Time = 23.6195720000012
# (Device-75)Standard deviation  Round Trip Time = 1.2789060718539815
# (Device-75)Min Round Trip Time = 21.170578999999634
# (Device-75)Max Round Trip Time = 25.84336099999973
# ---------------------------------------------------------------
# (Device-76)Mean Round Trip Time = 23.049821346735605
# (Device-76)Median Round Trip Time = 22.99565700002404
# (Device-76)Standard deviation  Round Trip Time = 1.1836687586631005
# (Device-76)Min Round Trip Time = 21.046233999982178
# (Device-76)Max Round Trip Time = 25.11249699999496
# ---------------------------------------------------------------
# (Device-77)Mean Round Trip Time = 23.885252356784825
# (Device-77)Median Round Trip Time = 23.812687999999582
# (Device-77)Standard deviation  Round Trip Time = 3.0624982954756743
# (Device-77)Min Round Trip Time = 21.554774999913207
# (Device-77)Max Round Trip Time = 63.735724000025584
# ---------------------------------------------------------------
# (Device-78)Mean Round Trip Time = 22.689216497487894
# (Device-78)Median Round Trip Time = 22.5096810000025
# (Device-78)Standard deviation  Round Trip Time = 1.2312203519911016
# (Device-78)Min Round Trip Time = 20.622588000037467
# (Device-78)Max Round Trip Time = 24.8684250000224
# ---------------------------------------------------------------
# (Device-79)Mean Round Trip Time = 22.662750190955748
# (Device-79)Median Round Trip Time = 22.6852629999712
# (Device-79)Standard deviation  Round Trip Time = 1.29077850262089
# (Device-79)Min Round Trip Time = 20.60070199996744
# (Device-79)Max Round Trip Time = 31.023984000000837
# ---------------------------------------------------------------
# (Device-80)Mean Round Trip Time = 22.57661599999998
# (Device-80)Median Round Trip Time = 22.691764000001058
# (Device-80)Standard deviation  Round Trip Time = 1.1879635000489743
# (Device-80)Min Round Trip Time = 20.191879999970297
# (Device-80)Max Round Trip Time = 24.75920999995651
# ---------------------------------------------------------------
# (Device-81)Mean Round Trip Time = 22.795397206031037
# (Device-81)Median Round Trip Time = 22.646460000004254
# (Device-81)Standard deviation  Round Trip Time = 1.2332947405631947
# (Device-81)Min Round Trip Time = 20.515332000002218
# (Device-81)Max Round Trip Time = 25.440189000008218
# ---------------------------------------------------------------
# (Device-82)Mean Round Trip Time = 22.75621361306588
# (Device-82)Median Round Trip Time = 22.81293400000095
# (Device-82)Standard deviation  Round Trip Time = 1.1607361939245158
# (Device-82)Min Round Trip Time = 20.548432999987654
# (Device-82)Max Round Trip Time = 25.102349999997386
# ---------------------------------------------------------------
# (Device-83)Mean Round Trip Time = 23.617733412060602
# (Device-83)Median Round Trip Time = 23.437417999957688
# (Device-83)Standard deviation  Round Trip Time = 1.1682887366139136
# (Device-83)Min Round Trip Time = 21.560519999979988
# (Device-83)Max Round Trip Time = 25.66406400001142
# ---------------------------------------------------------------
# (Device-84)Mean Round Trip Time = 23.65373895476945
# (Device-84)Median Round Trip Time = 23.580317000011064
# (Device-84)Standard deviation  Round Trip Time = 1.1082616359698982
# (Device-84)Min Round Trip Time = 21.501338000000203
# (Device-84)Max Round Trip Time = 25.790726000025188
# ---------------------------------------------------------------
# (Device-85)Mean Round Trip Time = 22.681275527641255
# (Device-85)Median Round Trip Time = 22.79313099995761
# (Device-85)Standard deviation  Round Trip Time = 1.1741589576402611
# (Device-85)Min Round Trip Time = 20.37081899993609
# (Device-85)Max Round Trip Time = 24.837544999996908
# ---------------------------------------------------------------
# (Device-86)Mean Round Trip Time = 22.9644616783885
# (Device-86)Median Round Trip Time = 22.96390000003612
# (Device-86)Standard deviation  Round Trip Time = 1.156323208394945
# (Device-86)Min Round Trip Time = 20.573494999993613
# (Device-86)Max Round Trip Time = 25.261700000015708
# ---------------------------------------------------------------
# (Device-87)Mean Round Trip Time = 23.442295462310128
# (Device-87)Median Round Trip Time = 23.227318000010655
# (Device-87)Standard deviation  Round Trip Time = 3.3198869715834083
# (Device-87)Min Round Trip Time = 21.075092999922163
# (Device-87)Max Round Trip Time = 67.03642000002219
# ---------------------------------------------------------------
# (Device-88)Mean Round Trip Time = 22.642124110553567
# (Device-88)Median Round Trip Time = 22.58079099999577
# (Device-88)Standard deviation  Round Trip Time = 1.1822294684373913
# (Device-88)Min Round Trip Time = 20.602450999994915
# (Device-88)Max Round Trip Time = 24.928076999970017
# ---------------------------------------------------------------
# (Device-89)Mean Round Trip Time = 22.719205809043093
# (Device-89)Median Round Trip Time = 22.876450000012483
# (Device-89)Standard deviation  Round Trip Time = 1.2050185884475415
# (Device-89)Min Round Trip Time = 20.473361000000523
# (Device-89)Max Round Trip Time = 24.726851999957944
# ---------------------------------------------------------------
# (Device-90)Mean Round Trip Time = 22.677692432162154
# (Device-90)Median Round Trip Time = 22.62967399997251
# (Device-90)Standard deviation  Round Trip Time = 1.2941151479380728
# (Device-90)Min Round Trip Time = 20.593351000002258
# (Device-90)Max Round Trip Time = 28.361462000020765
# ---------------------------------------------------------------
# (Device-91)Mean Round Trip Time = 23.197404497487316
# (Device-91)Median Round Trip Time = 23.15532800000142
# (Device-91)Standard deviation  Round Trip Time = 1.1731804119943736
# (Device-91)Min Round Trip Time = 21.08375000000251
# (Device-91)Max Round Trip Time = 25.231615999999235
# ---------------------------------------------------------------
# (Device-92)Mean Round Trip Time = 23.256674241207183
# (Device-92)Median Round Trip Time = 23.342307999996592
# (Device-92)Standard deviation  Round Trip Time = 1.082236967510368
# (Device-92)Min Round Trip Time = 21.17657000002282
# (Device-92)Max Round Trip Time = 25.40331900002002
# ---------------------------------------------------------------
# (Device-93)Mean Round Trip Time = 23.666718562816815
# (Device-93)Median Round Trip Time = 23.642786000038996
# (Device-93)Standard deviation  Round Trip Time = 1.194786785642755
# (Device-93)Min Round Trip Time = 21.472511000013128
# (Device-93)Max Round Trip Time = 26.00299900001346
# ---------------------------------------------------------------
# (Device-94)Mean Round Trip Time = 22.7757636231171
# (Device-94)Median Round Trip Time = 22.8449640000008
# (Device-94)Standard deviation  Round Trip Time = 1.1090689476718905
# (Device-94)Min Round Trip Time = 20.56009499999334
# (Device-94)Max Round Trip Time = 24.818392000042877
# ---------------------------------------------------------------
# (Device-95)Mean Round Trip Time = 23.588515437185016
# (Device-95)Median Round Trip Time = 23.48244799998156
# (Device-95)Standard deviation  Round Trip Time = 1.1493652584168528
# (Device-95)Min Round Trip Time = 21.56453100002409
# (Device-95)Max Round Trip Time = 25.717794999991384
# ---------------------------------------------------------------
# (Device-96)Mean Round Trip Time = 23.67421438693504
# (Device-96)Median Round Trip Time = 23.69050300001163
# (Device-96)Standard deviation  Round Trip Time = 1.18092928309855
# (Device-96)Min Round Trip Time = 21.23942800005807
# (Device-96)Max Round Trip Time = 25.974263999955838
# ---------------------------------------------------------------
# (Device-97)Mean Round Trip Time = 22.887972613067465
# (Device-97)Median Round Trip Time = 22.84906299999534
# (Device-97)Standard deviation  Round Trip Time = 1.1430735723731758
# (Device-97)Min Round Trip Time = 20.759347000023354
# (Device-97)Max Round Trip Time = 24.960190000001603
# ---------------------------------------------------------------
# (Device-98)Mean Round Trip Time = 23.134974130654935
# (Device-98)Median Round Trip Time = 23.159191999980067
# (Device-98)Standard deviation  Round Trip Time = 1.1074571874872419
# (Device-98)Min Round Trip Time = 20.885145000022476
# (Device-98)Max Round Trip Time = 25.30122199999596
# ---------------------------------------------------------------
# (Device-99)Mean Round Trip Time = 22.741894753769277
# (Device-99)Median Round Trip Time = 22.85970399998405
# (Device-99)Standard deviation  Round Trip Time = 1.1617404123076802
# (Device-99)Min Round Trip Time = 20.600613000056
# (Device-99)Max Round Trip Time = 25.184045000003152
# ---------------------------------------------------------------
# (Device-100)Mean Round Trip Time = 23.702404542713627
# (Device-100)Median Round Trip Time = 23.564358999976776
# (Device-100)Standard deviation  Round Trip Time = 1.3317353435372643
# (Device-100)Min Round Trip Time = 21.400259999950322
# (Device-100)Max Round Trip Time = 32.942278999939845
# ---------------------------------------------------------------

# %% [markdown]
# # CÁLCULO DO TAMANHO DA AMOSTRA

# %%
nivel_de_significancia = 0.05

# %%
nivel_de_confiança = 1 - nivel_de_significancia
nivel_de_confiança
# Out:
# 0.95

# %%
#Calculando o z com scipy
z = scipy.stats.norm.ppf(0.975)
z
# Out:
# 1.959963984540054

# %% [markdown]
# Com nosso z calculado podemos seguir adiante
#
# ### $$z = 1.959963984540054 $$
#
# Abaixo segue algumas formulas que iremos utilizar para calcular o numero de amostra

# %% [markdown]
# ### Calculando o tamanho da nossa amostra

# %%
df_concatenado = pd.concat(data.values())
desvio_padrao_amostral = df_concatenado["RTT"].std()
media = df_concatenado["RTT"].mean()
e = 0.05 * media
n = (z * ( desvio_padrao_amostral/e) )**2
n
# Out:
# 10.946741559786311

# %%
e = df_concatenado["RTT"].mean() * 0.05

# %%
desvio_padrao_amostral
# Out:
# 1.9514935831727538

# %%
import matplotlib 
i=1
fig, ax = plt.subplots(figsize=(10,5),dpi=72)
for port in ports:
  ax.scatter(data[port]["RTT"].index,data[port]["RTT"], label='Dispositivo-{}'.format(i))
  ax.set_ylabel('Round Trip Time (ms)')
  ax.set_xlabel('Quantidade de Publicação')
  ax.set_title('Gráfico de dispersão (Round Trip Time)')
#   ax.hlines(data[port]["RTT"].max(),  xmin=0, xmax=620, colors="red", linestyles="dashed", label="Maior Medição")
#   ax.hlines(data[port]["RTT"].min(),  xmin=0, xmax=620, colors="green", linestyles="dashed", label="Menor Medição")
  ax.legend()
  i+=1

# %%
df_concatenado["RTT"].mean()
# Out:
# 23.12079599613073

# %%
df_concatenado["RTT"].to_csv("dados.csv", index=False)
