# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import scipy
import numpy as np
import seaborn as sns

# %% [markdown]
# Objetivos do Script:
#
# Esse script tem como objetivo ler os dados que foram capturados da nossa amostra piloto e realizar alguns estudos em cima desses dados.
#
# Os 6 primeiros tópicos que eu separei abaixo são utilizados na grande maioria dos scripts de tratamento de dados desse estudo.
# Deixei padronizado para que seja possivel tratar simulações com um dispositivo ou vários.
#
# Sumário:
#   - Leitura dos dados
#   - Separar publicações e confirmação de entrega por dispositivo simulado.
#   - Criação de um dataframe com informações capturadas.
#   - Medidas de tendência centrar por dispositivo
#   - Medidas de tendência centrar de todos os dispositivos.
#   - Gráfico de dispersão da amostra.
#   - Calculo do tamanho da amostra.
#
# Como estamos trabalhando com uma amostra piloto temos como objetivo calcular o tamanho das amostras isso será realizado na ultima parte desse script.

# %%
data = pd.read_csv("./data.csv")
ports = data["Source Port"].unique()
ports = ports[ports !=1883]
data
# Out:
#           No.         Time           Source      Destination Protocol  Length  \
# 0        5932    44.381336     192.168.15.4  130.185.238.170     MQTT      89
# 1        5936    44.460250     192.168.15.4  130.185.238.170     MQTT     354
# 2        5937    44.462036  130.185.238.170     192.168.15.4     MQTT      70
# 3        5941    44.538840  130.185.238.170     192.168.15.4     MQTT     345
# 4        5960    45.379193     192.168.15.4  130.185.238.170     MQTT      89
# ...       ...          ...              ...              ...      ...     ...
# 63345  171924  1076.322098  130.185.238.170     192.168.15.4     MQTT      68
# 63346  171928  1076.442205     192.168.15.4  130.185.238.170     MQTT      68
# 63347  171931  1076.516936  130.185.238.170     192.168.15.4     MQTT      68
# 63348  171983  1078.774633     192.168.15.4  130.185.238.170     MQTT      68
# 63349  171988  1078.850675  130.185.238.170     192.168.15.4     MQTT      68
#
#        Source Port Message Identifier  Destination Port  \
# 0            49957                NaN              1883
# 1            49957                1,2              1883
# 2             1883                NaN             49957
# 3             1883                1,2             49957
# 4            45977                NaN              1883
# ...            ...                ...               ...
# 63345         1883                NaN             50589
# 63346        58853                NaN              1883
# 63347         1883                NaN             58853
# 63348        39531                NaN              1883
# 63349         1883                NaN             39531
#
#                                                     Info
# 0                                        Connect Command
# 1      Subscribe Request (id=1) [devices-1], Publish ...
# 2                                            Connect Ack
# 3      Subscribe Ack (id=1), Publish Message [devices...
# 4                                        Connect Command
# ...                                                  ...
# 63345                                      Ping Response
# 63346                                       Ping Request
# 63347                                      Ping Response
# 63348                                       Ping Request
# 63349                                      Ping Response
#
# [63350 rows x 10 columns]

# %%
#  - Separar publicações e confirmação de entrega por dispositivo simulado.
devices = {}
#  : devices será um dicionario que irá ter uma chave referente ao device e o valor será um dataframe referente aos respectivos devices 
for port in ports:  
  data = data.loc[ ~(data["Message Identifier"] == "1,2")]
  # data["Message Identifier"].dropna(replace=True)
  array_publish = data.loc[data["Source Port"] == port].dropna(subset=['Message Identifier'])
  array_publish_ack = data.loc[data["Destination Port"] == port].dropna(subset=['Message Identifier'])
  device = {"publish":array_publish, "publish_ack" : array_publish_ack}
  devices[port] = device

# %%
devicesNew = devices.copy()
for index in devices:
    if len(devices[index]["publish"]) <= 0:
        ports = ports[ports !=index]

# %%
# - Criação de um dataframe com informações capturadas acima. 
data = {}
for port in ports:
    RTT = pd.DataFrame(columns=["Time_publish", "Time_ack"])
    for index, row in devices[port]["publish"].iterrows():
        id = int(row["Message Identifier"])
        time_publish = row["Time"]
        RTT.loc[id, "Time_publish"] = time_publish 

    for index, row in devices[port]["publish_ack"].iterrows():
        id = int(row["Message Identifier"])
        time_publish = row["Time"]
        RTT.loc[id, "Time_ack"] = time_publish
    RTT.loc[id, "Time_ack"] = time_publish
    RTT["RTT"]  =(RTT["Time_ack"] - RTT["Time_publish"] )* 1000
    data[port] = RTT

# %% [markdown]
# ## Medidas de Tendência Central Por Device

# %%
i=1
data_mean = []
data_median = []
data_std = []
data_min = []
data_max = []

for port in ports:
  data_mean.append(data[port]["RTT"].mean())
  data_median.append(data[port]["RTT"].mean())
  data_std.append(data[port]["RTT"].mean())
  data_min.append(data[port]["RTT"].mean())
  data_max.append(data[port]["RTT"].mean())

  print("(Device-{})Mean Round Trip Time = {}".format(i ,data[port]["RTT"].mean()))
  print("(Device-{})Median Round Trip Time = {}".format(i ,data[port]["RTT"].median()))
  print("(Device-{})Standard deviation  Round Trip Time = {}".format(i ,data[port]["RTT"].std()))
  print("(Device-{})Min Round Trip Time = {}".format(i ,data[port]["RTT"].min()))
  print("(Device-{})Max Round Trip Time = {}".format(i ,data[port]["RTT"].max()))
  print("---------------------------------------------------------------")

  i+=1
# Out:
# (Device-1)Mean Round Trip Time = 153.9097593768836
# (Device-1)Median Round Trip Time = 152.84546100002672
# (Device-1)Standard deviation  Round Trip Time = 6.772859935249185
# (Device-1)Min Round Trip Time = 149.9532619999968
# (Device-1)Max Round Trip Time = 240.50177999998823
# ---------------------------------------------------------------
# (Device-2)Mean Round Trip Time = 154.70691190451842
# (Device-2)Median Round Trip Time = 152.05762099992626
# (Device-2)Standard deviation  Round Trip Time = 22.132660526488763
# (Device-2)Min Round Trip Time = 148.95066999997653
# (Device-2)Max Round Trip Time = 453.2991730000049
# ---------------------------------------------------------------
# (Device-3)Mean Round Trip Time = 151.45207428140625
# (Device-3)Median Round Trip Time = 150.59046600003967
# (Device-3)Standard deviation  Round Trip Time = 4.128210253495923
# (Device-3)Min Round Trip Time = 144.8314719999928
# (Device-3)Max Round Trip Time = 192.22716600000922
# ---------------------------------------------------------------
# (Device-4)Mean Round Trip Time = 162.07276511557356
# (Device-4)Median Round Trip Time = 160.9702650000031
# (Device-4)Standard deviation  Round Trip Time = 4.376150017957178
# (Device-4)Min Round Trip Time = 158.05784500003028
# (Device-4)Max Round Trip Time = 203.83340099999714
# ---------------------------------------------------------------
# (Device-5)Mean Round Trip Time = 152.46999943718777
# (Device-5)Median Round Trip Time = 150.57697499997857
# (Device-5)Standard deviation  Round Trip Time = 14.960491386546146
# (Device-5)Min Round Trip Time = 148.2920959999916
# (Device-5)Max Round Trip Time = 356.53444600001194
# ---------------------------------------------------------------
# (Device-6)Mean Round Trip Time = 159.1665185829144
# (Device-6)Median Round Trip Time = 158.37613000002193
# (Device-6)Standard deviation  Round Trip Time = 4.898833407283311
# (Device-6)Min Round Trip Time = 152.00702100000285
# (Device-6)Max Round Trip Time = 205.48746700001175
# ---------------------------------------------------------------
# (Device-7)Mean Round Trip Time = 152.6064593266345
# (Device-7)Median Round Trip Time = 151.36803699999746
# (Device-7)Standard deviation  Round Trip Time = 6.322679505027428
# (Device-7)Min Round Trip Time = 148.51950099989608
# (Device-7)Max Round Trip Time = 221.3664230000063
# ---------------------------------------------------------------
# (Device-8)Mean Round Trip Time = 151.59411276381883
# (Device-8)Median Round Trip Time = 150.478961999994
# (Device-8)Standard deviation  Round Trip Time = 7.215555254562718
# (Device-8)Min Round Trip Time = 145.67094200000952
# (Device-8)Max Round Trip Time = 232.1433689999708
# ---------------------------------------------------------------
# (Device-9)Mean Round Trip Time = 151.9160969095479
# (Device-9)Median Round Trip Time = 151.14540999996962
# (Device-9)Standard deviation  Round Trip Time = 2.949252887035789
# (Device-9)Min Round Trip Time = 148.62827600006767
# (Device-9)Max Round Trip Time = 164.51376800000617
# ---------------------------------------------------------------
# (Device-10)Mean Round Trip Time = 158.83080008543104
# (Device-10)Median Round Trip Time = 158.2619959999647
# (Device-10)Standard deviation  Round Trip Time = 4.488388857500979
# (Device-10)Min Round Trip Time = 152.1439530000066
# (Device-10)Max Round Trip Time = 203.71542300000556
# ---------------------------------------------------------------
# (Device-11)Mean Round Trip Time = 153.19922394975129
# (Device-11)Median Round Trip Time = 152.54436300000407
# (Device-11)Standard deviation  Round Trip Time = 3.251885208409712
# (Device-11)Min Round Trip Time = 149.70478500003992
# (Device-11)Max Round Trip Time = 174.84759600000643
# ---------------------------------------------------------------
# (Device-12)Mean Round Trip Time = 162.01129311055115
# (Device-12)Median Round Trip Time = 160.6438509999748
# (Device-12)Standard deviation  Round Trip Time = 8.468996185402997
# (Device-12)Min Round Trip Time = 158.12155899999425
# (Device-12)Max Round Trip Time = 271.8685950000008
# ---------------------------------------------------------------
# (Device-13)Mean Round Trip Time = 153.27789351256462
# (Device-13)Median Round Trip Time = 152.26246800000354
# (Device-13)Standard deviation  Round Trip Time = 4.932775649006351
# (Device-13)Min Round Trip Time = 149.82073400005902
# (Device-13)Max Round Trip Time = 195.78167999998186
# ---------------------------------------------------------------
# (Device-14)Mean Round Trip Time = 146.46464026633475
# (Device-14)Median Round Trip Time = 144.6486749999849
# (Device-14)Standard deviation  Round Trip Time = 8.192430815981584
# (Device-14)Min Round Trip Time = 142.07042799995406
# (Device-14)Max Round Trip Time = 248.36831599998277
# ---------------------------------------------------------------
# (Device-15)Mean Round Trip Time = 153.53901134170275
# (Device-15)Median Round Trip Time = 152.6976179999906
# (Device-15)Standard deviation  Round Trip Time = 3.12013710184683
# (Device-15)Min Round Trip Time = 150.04427299993495
# (Device-15)Max Round Trip Time = 167.72988899992924
# ---------------------------------------------------------------
# (Device-16)Mean Round Trip Time = 161.44356052763885
# (Device-16)Median Round Trip Time = 160.18580100001145
# (Device-16)Standard deviation  Round Trip Time = 5.001390237401275
# (Device-16)Min Round Trip Time = 157.02910599998177
# (Device-16)Max Round Trip Time = 205.181347000007
# ---------------------------------------------------------------
# (Device-17)Mean Round Trip Time = 145.6785227537664
# (Device-17)Median Round Trip Time = 144.9404509999681
# (Device-17)Standard deviation  Round Trip Time = 3.104127177147237
# (Device-17)Min Round Trip Time = 142.10772399999883
# (Device-17)Max Round Trip Time = 160.2194010000062
# ---------------------------------------------------------------
# (Device-18)Mean Round Trip Time = 161.1018933065286
# (Device-18)Median Round Trip Time = 160.21810399990954
# (Device-18)Standard deviation  Round Trip Time = 4.234533655267636
# (Device-18)Min Round Trip Time = 157.6489439999591
# (Device-18)Max Round Trip Time = 203.66349900001524
# ---------------------------------------------------------------
# (Device-19)Mean Round Trip Time = 145.24441328140475
# (Device-19)Median Round Trip Time = 144.54764599997816
# (Device-19)Standard deviation  Round Trip Time = 2.7078826931855398
# (Device-19)Min Round Trip Time = 141.92183399995884
# (Device-19)Max Round Trip Time = 156.39310500000647
# ---------------------------------------------------------------
# (Device-20)Mean Round Trip Time = 152.25401471859197
# (Device-20)Median Round Trip Time = 151.83493900002532
# (Device-20)Standard deviation  Round Trip Time = 2.208636680248767
# (Device-20)Min Round Trip Time = 149.27101299997503
# (Device-20)Max Round Trip Time = 159.74425000001702
# ---------------------------------------------------------------
# (Device-21)Mean Round Trip Time = 161.71572221105538
# (Device-21)Median Round Trip Time = 161.13889700000072
# (Device-21)Standard deviation  Round Trip Time = 2.930480707301228
# (Device-21)Min Round Trip Time = 158.10528800000156
# (Device-21)Max Round Trip Time = 179.3446380000887
# ---------------------------------------------------------------
# (Device-22)Mean Round Trip Time = 156.3746089346736
# (Device-22)Median Round Trip Time = 155.40424900001426
# (Device-22)Standard deviation  Round Trip Time = 3.570700601043015
# (Device-22)Min Round Trip Time = 151.73473599998033
# (Device-22)Max Round Trip Time = 169.5139849999805
# ---------------------------------------------------------------
# (Device-23)Mean Round Trip Time = 161.7457729899508
# (Device-23)Median Round Trip Time = 160.87841600000274
# (Device-23)Standard deviation  Round Trip Time = 3.3634722032786857
# (Device-23)Min Round Trip Time = 157.89951900001142
# (Device-23)Max Round Trip Time = 174.26188800004638
# ---------------------------------------------------------------
# (Device-24)Mean Round Trip Time = 154.4216487587926
# (Device-24)Median Round Trip Time = 152.33455800000684
# (Device-24)Standard deviation  Round Trip Time = 17.024581674974673
# (Device-24)Min Round Trip Time = 149.55623400000206
# (Device-24)Max Round Trip Time = 389.5643919999543
# ---------------------------------------------------------------
# (Device-25)Mean Round Trip Time = 152.01841019597924
# (Device-25)Median Round Trip Time = 150.6630170000136
# (Device-25)Standard deviation  Round Trip Time = 8.315224000850947
# (Device-25)Min Round Trip Time = 145.39886400001478
# (Device-25)Max Round Trip Time = 240.75763899998037
# ---------------------------------------------------------------
# (Device-26)Mean Round Trip Time = 161.0359261909563
# (Device-26)Median Round Trip Time = 160.20690400000603
# (Device-26)Standard deviation  Round Trip Time = 4.384050612245575
# (Device-26)Min Round Trip Time = 157.51054500000805
# (Device-26)Max Round Trip Time = 208.09009499998865
# ---------------------------------------------------------------
# (Device-27)Mean Round Trip Time = 146.08348410050226
# (Device-27)Median Round Trip Time = 144.96030600002996
# (Device-27)Standard deviation  Round Trip Time = 4.255470899455079
# (Device-27)Min Round Trip Time = 141.99045999998816
# (Device-27)Max Round Trip Time = 184.00901200004682
# ---------------------------------------------------------------
# (Device-28)Mean Round Trip Time = 145.58299927638356
# (Device-28)Median Round Trip Time = 144.64332699998295
# (Device-28)Standard deviation  Round Trip Time = 4.627316488710304
# (Device-28)Min Round Trip Time = 142.19428999996353
# (Device-28)Max Round Trip Time = 196.89180899996472
# ---------------------------------------------------------------
# (Device-29)Mean Round Trip Time = 161.7254508844241
# (Device-29)Median Round Trip Time = 160.9021470000016
# (Device-29)Standard deviation  Round Trip Time = 3.197556587126116
# (Device-29)Min Round Trip Time = 157.98425899998847
# (Device-29)Max Round Trip Time = 176.65688099998533
# ---------------------------------------------------------------
# (Device-30)Mean Round Trip Time = 161.65691232663136
# (Device-30)Median Round Trip Time = 160.63126000000238
# (Device-30)Standard deviation  Round Trip Time = 3.322880739321298
# (Device-30)Min Round Trip Time = 157.9615160000003
# (Device-30)Max Round Trip Time = 176.06834899999058
# ---------------------------------------------------------------
# (Device-31)Mean Round Trip Time = 158.767872994974
# (Device-31)Median Round Trip Time = 158.43742999999222
# (Device-31)Standard deviation  Round Trip Time = 2.4345333759593184
# (Device-31)Min Round Trip Time = 152.91365000007318
# (Device-31)Max Round Trip Time = 167.52843400001893
# ---------------------------------------------------------------
# (Device-32)Mean Round Trip Time = 161.23879322110005
# (Device-32)Median Round Trip Time = 160.5891880000172
# (Device-32)Standard deviation  Round Trip Time = 3.148395391740181
# (Device-32)Min Round Trip Time = 157.65998599999875
# (Device-32)Max Round Trip Time = 171.98936299996603
# ---------------------------------------------------------------
# (Device-33)Mean Round Trip Time = 152.8667937989911
# (Device-33)Median Round Trip Time = 151.82690500000717
# (Device-33)Standard deviation  Round Trip Time = 4.8378309671201905
# (Device-33)Min Round Trip Time = 149.27735100002337
# (Device-33)Max Round Trip Time = 200.19122599995853
# ---------------------------------------------------------------
# (Device-34)Mean Round Trip Time = 153.35711975376793
# (Device-34)Median Round Trip Time = 152.4596410000072
# (Device-34)Standard deviation  Round Trip Time = 3.477352815193899
# (Device-34)Min Round Trip Time = 149.581301000012
# (Device-34)Max Round Trip Time = 171.27236400000356
# ---------------------------------------------------------------
# (Device-35)Mean Round Trip Time = 146.1138186331665
# (Device-35)Median Round Trip Time = 145.02523300001258
# (Device-35)Standard deviation  Round Trip Time = 5.092305345926046
# (Device-35)Min Round Trip Time = 142.54032400000938
# (Device-35)Max Round Trip Time = 188.0726599999889
# ---------------------------------------------------------------
# (Device-36)Mean Round Trip Time = 145.23587302010188
# (Device-36)Median Round Trip Time = 144.29158899997674
# (Device-36)Standard deviation  Round Trip Time = 4.066276907275446
# (Device-36)Min Round Trip Time = 141.68013899995913
# (Device-36)Max Round Trip Time = 183.78019700003279
# ---------------------------------------------------------------
# (Device-37)Mean Round Trip Time = 160.96460807035132
# (Device-37)Median Round Trip Time = 160.2088340000023
# (Device-37)Standard deviation  Round Trip Time = 2.938241080573335
# (Device-37)Min Round Trip Time = 157.5643039999477
# (Device-37)Max Round Trip Time = 174.35337199992773
# ---------------------------------------------------------------
# (Device-38)Mean Round Trip Time = 161.8187971407054
# (Device-38)Median Round Trip Time = 160.5413990000102
# (Device-38)Standard deviation  Round Trip Time = 7.886128784043321
# (Device-38)Min Round Trip Time = 157.41360300000906
# (Device-38)Max Round Trip Time = 258.7616029999822
# ---------------------------------------------------------------
# (Device-39)Mean Round Trip Time = 159.28156976883812
# (Device-39)Median Round Trip Time = 158.5706560000517
# (Device-39)Standard deviation  Round Trip Time = 4.1785668215135265
# (Device-39)Min Round Trip Time = 154.75399899992226
# (Device-39)Max Round Trip Time = 200.08524099998226
# ---------------------------------------------------------------
# (Device-40)Mean Round Trip Time = 153.3270434422107
# (Device-40)Median Round Trip Time = 152.316952000092
# (Device-40)Standard deviation  Round Trip Time = 6.572741233320608
# (Device-40)Min Round Trip Time = 149.59612999999194
# (Device-40)Max Round Trip Time = 236.7187009999725
# ---------------------------------------------------------------
# (Device-41)Mean Round Trip Time = 154.35023172864268
# (Device-41)Median Round Trip Time = 152.3597550000204
# (Device-41)Standard deviation  Round Trip Time = 21.804865446900827
# (Device-41)Min Round Trip Time = 149.21181699997987
# (Device-41)Max Round Trip Time = 457.63080199998285
# ---------------------------------------------------------------
# (Device-42)Mean Round Trip Time = 145.73001317588054
# (Device-42)Median Round Trip Time = 144.96140500000365
# (Device-42)Standard deviation  Round Trip Time = 3.3298461596922264
# (Device-42)Min Round Trip Time = 142.1586060000095
# (Device-42)Max Round Trip Time = 159.47656299999835
# ---------------------------------------------------------------
# (Device-43)Mean Round Trip Time = 161.04678504020154
# (Device-43)Median Round Trip Time = 160.2421280000499
# (Device-43)Standard deviation  Round Trip Time = 3.0749380407412774
# (Device-43)Min Round Trip Time = 157.45563600000878
# (Device-43)Max Round Trip Time = 175.94373899999027
# ---------------------------------------------------------------
# (Device-44)Mean Round Trip Time = 153.82431815577652
# (Device-44)Median Round Trip Time = 152.62558799999226
# (Device-44)Standard deviation  Round Trip Time = 5.190817219025517
# (Device-44)Min Round Trip Time = 149.6952349999674
# (Device-44)Max Round Trip Time = 195.6471009999916
# ---------------------------------------------------------------
# (Device-45)Mean Round Trip Time = 145.15170991457376
# (Device-45)Median Round Trip Time = 144.3417569999781
# (Device-45)Standard deviation  Round Trip Time = 3.236056054939038
# (Device-45)Min Round Trip Time = 141.54992400005995
# (Device-45)Max Round Trip Time = 161.40726100002212
# ---------------------------------------------------------------
# (Device-46)Mean Round Trip Time = 162.3296400502493
# (Device-46)Median Round Trip Time = 160.29017199997497
# (Device-46)Standard deviation  Round Trip Time = 17.063056877993645
# (Device-46)Min Round Trip Time = 157.55064699999366
# (Device-46)Max Round Trip Time = 396.6181190000384
# ---------------------------------------------------------------
# (Device-47)Mean Round Trip Time = 160.23912411558192
# (Device-47)Median Round Trip Time = 158.26737700001559
# (Device-47)Standard deviation  Round Trip Time = 15.927424107993527
# (Device-47)Min Round Trip Time = 152.77706899999544
# (Device-47)Max Round Trip Time = 369.87046800004464
# ---------------------------------------------------------------
# (Device-48)Mean Round Trip Time = 154.20911826130518
# (Device-48)Median Round Trip Time = 152.84739000003356
# (Device-48)Standard deviation  Round Trip Time = 5.897848239979392
# (Device-48)Min Round Trip Time = 149.9717670000109
# (Device-48)Max Round Trip Time = 211.61121099999036
# ---------------------------------------------------------------
# (Device-49)Mean Round Trip Time = 153.0007543869367
# (Device-49)Median Round Trip Time = 152.00423800001772
# (Device-49)Standard deviation  Round Trip Time = 6.193145601110852
# (Device-49)Min Round Trip Time = 149.2394810000235
# (Device-49)Max Round Trip Time = 229.99180799996566
# ---------------------------------------------------------------
# (Device-50)Mean Round Trip Time = 152.29212677889646
# (Device-50)Median Round Trip Time = 150.93889099995295
# (Device-50)Standard deviation  Round Trip Time = 5.599334719160367
# (Device-50)Min Round Trip Time = 148.25447999999142
# (Device-50)Max Round Trip Time = 197.9042269999809
# ---------------------------------------------------------------
# (Device-51)Mean Round Trip Time = 153.49667836180961
# (Device-51)Median Round Trip Time = 152.7518999999984
# (Device-51)Standard deviation  Round Trip Time = 2.978840346392896
# (Device-51)Min Round Trip Time = 150.02631700002667
# (Device-51)Max Round Trip Time = 165.79917700005353
# ---------------------------------------------------------------
# (Device-52)Mean Round Trip Time = 153.50105300000058
# (Device-52)Median Round Trip Time = 152.5324339999088
# (Device-52)Standard deviation  Round Trip Time = 4.23613436896119
# (Device-52)Min Round Trip Time = 149.80284399996435
# (Device-52)Max Round Trip Time = 185.2975269999888
# ---------------------------------------------------------------
# (Device-53)Mean Round Trip Time = 152.92053702009997
# (Device-53)Median Round Trip Time = 152.17611099990336
# (Device-53)Standard deviation  Round Trip Time = 2.692603782360768
# (Device-53)Min Round Trip Time = 149.70535599999835
# (Device-53)Max Round Trip Time = 165.1134329999877
# ---------------------------------------------------------------
# (Device-54)Mean Round Trip Time = 150.41930486934666
# (Device-54)Median Round Trip Time = 150.28939199999058
# (Device-54)Standard deviation  Round Trip Time = 2.7146271186903737
# (Device-54)Min Round Trip Time = 144.79681800003164
# (Device-54)Max Round Trip Time = 161.88181900000131
# ---------------------------------------------------------------
# (Device-55)Mean Round Trip Time = 162.19471991960035
# (Device-55)Median Round Trip Time = 161.0550720000674
# (Device-55)Standard deviation  Round Trip Time = 6.676913120621583
# (Device-55)Min Round Trip Time = 157.61331300001302
# (Device-55)Max Round Trip Time = 236.29239299998517
# ---------------------------------------------------------------
# (Device-56)Mean Round Trip Time = 145.44087090954673
# (Device-56)Median Round Trip Time = 144.4344919999594
# (Device-56)Standard deviation  Round Trip Time = 5.106029380130148
# (Device-56)Min Round Trip Time = 142.08091499999398
# (Device-56)Max Round Trip Time = 205.41074799996295
# ---------------------------------------------------------------
# (Device-57)Mean Round Trip Time = 153.51352793970085
# (Device-57)Median Round Trip Time = 152.5964270000486
# (Device-57)Standard deviation  Round Trip Time = 4.473113629697743
# (Device-57)Min Round Trip Time = 149.51961500003108
# (Device-57)Max Round Trip Time = 197.6440630000127
# ---------------------------------------------------------------
# (Device-58)Mean Round Trip Time = 153.82548266834036
# (Device-58)Median Round Trip Time = 152.79513099997644
# (Device-58)Standard deviation  Round Trip Time = 4.99630481453344
# (Device-58)Min Round Trip Time = 148.5580119999952
# (Device-58)Max Round Trip Time = 207.57462099999202
# ---------------------------------------------------------------
# (Device-59)Mean Round Trip Time = 145.928986150759
# (Device-59)Median Round Trip Time = 144.423058999962
# (Device-59)Standard deviation  Round Trip Time = 6.076094370017942
# (Device-59)Min Round Trip Time = 142.13055699997312
# (Device-59)Max Round Trip Time = 216.10555699999168
# ---------------------------------------------------------------
# (Device-60)Mean Round Trip Time = 146.31747891457005
# (Device-60)Median Round Trip Time = 144.70658899995215
# (Device-60)Standard deviation  Round Trip Time = 15.96883923608503
# (Device-60)Min Round Trip Time = 141.78121499999463
# (Device-60)Max Round Trip Time = 367.2512759999904
# ---------------------------------------------------------------
# (Device-61)Mean Round Trip Time = 152.4986023165844
# (Device-61)Median Round Trip Time = 151.93444899989572
# (Device-61)Standard deviation  Round Trip Time = 2.9207972395181017
# (Device-61)Min Round Trip Time = 148.87098799999876
# (Device-61)Max Round Trip Time = 171.69782899998154
# ---------------------------------------------------------------
# (Device-62)Mean Round Trip Time = 151.10831928140828
# (Device-62)Median Round Trip Time = 150.44408599999315
# (Device-62)Standard deviation  Round Trip Time = 3.357581802846029
# (Device-62)Min Round Trip Time = 146.870186000001
# (Device-62)Max Round Trip Time = 181.0583289999954
# ---------------------------------------------------------------
# (Device-63)Mean Round Trip Time = 152.9639655075394
# (Device-63)Median Round Trip Time = 152.1143780000216
# (Device-63)Standard deviation  Round Trip Time = 3.5460370206603713
# (Device-63)Min Round Trip Time = 148.2526799999846
# (Device-63)Max Round Trip Time = 175.90900299995837
# ---------------------------------------------------------------
# (Device-64)Mean Round Trip Time = 154.18586652763685
# (Device-64)Median Round Trip Time = 153.09147100003884
# (Device-64)Standard deviation  Round Trip Time = 4.6184568013429566
# (Device-64)Min Round Trip Time = 150.298107000026
# (Device-64)Max Round Trip Time = 199.16815999999926
# ---------------------------------------------------------------
# (Device-65)Mean Round Trip Time = 145.4457143517589
# (Device-65)Median Round Trip Time = 144.68315500005247
# (Device-65)Standard deviation  Round Trip Time = 2.8568883445797604
# (Device-65)Min Round Trip Time = 142.04806800000824
# (Device-65)Max Round Trip Time = 160.42996900000617
# ---------------------------------------------------------------
# (Device-66)Mean Round Trip Time = 152.74005009045123
# (Device-66)Median Round Trip Time = 151.9375240000045
# (Device-66)Standard deviation  Round Trip Time = 2.995336614914439
# (Device-66)Min Round Trip Time = 149.5127240000329
# (Device-66)Max Round Trip Time = 169.9765790000356
# ---------------------------------------------------------------
# (Device-67)Mean Round Trip Time = 153.2836018743744
# (Device-67)Median Round Trip Time = 152.347973000019
# (Device-67)Standard deviation  Round Trip Time = 2.9686523906810325
# (Device-67)Min Round Trip Time = 149.79559100000017
# (Device-67)Max Round Trip Time = 165.96842000001288
# ---------------------------------------------------------------
# (Device-68)Mean Round Trip Time = 153.63826960301478
# (Device-68)Median Round Trip Time = 152.6886380000292
# (Device-68)Standard deviation  Round Trip Time = 6.329797081291637
# (Device-68)Min Round Trip Time = 149.89140599999473
# (Device-68)Max Round Trip Time = 229.0659880000021
# ---------------------------------------------------------------
# (Device-69)Mean Round Trip Time = 152.5719176683425
# (Device-69)Median Round Trip Time = 151.6582980000294
# (Device-69)Standard deviation  Round Trip Time = 4.551093499946969
# (Device-69)Min Round Trip Time = 149.37146599999096
# (Device-69)Max Round Trip Time = 193.40888300007464
# ---------------------------------------------------------------
# (Device-70)Mean Round Trip Time = 162.3602587386907
# (Device-70)Median Round Trip Time = 160.22020700006578
# (Device-70)Standard deviation  Round Trip Time = 15.7253453048405
# (Device-70)Min Round Trip Time = 157.53086400002303
# (Device-70)Max Round Trip Time = 376.99471299998777
# ---------------------------------------------------------------
# (Device-71)Mean Round Trip Time = 153.7490427487431
# (Device-71)Median Round Trip Time = 152.82196900000145
# (Device-71)Standard deviation  Round Trip Time = 3.5059240488755523
# (Device-71)Min Round Trip Time = 150.0745859999597
# (Device-71)Max Round Trip Time = 176.08214599999883
# ---------------------------------------------------------------
# (Device-72)Mean Round Trip Time = 151.43650088441882
# (Device-72)Median Round Trip Time = 150.75947999997652
# (Device-72)Standard deviation  Round Trip Time = 5.008162129791489
# (Device-72)Min Round Trip Time = 148.04583599999432
# (Device-72)Max Round Trip Time = 212.77687700001024
# ---------------------------------------------------------------
# (Device-73)Mean Round Trip Time = 150.83936693467467
# (Device-73)Median Round Trip Time = 150.34201700007088
# (Device-73)Standard deviation  Round Trip Time = 4.418250202611532
# (Device-73)Min Round Trip Time = 144.2038819999425
# (Device-73)Max Round Trip Time = 187.98541799998247
# ---------------------------------------------------------------
# (Device-74)Mean Round Trip Time = 153.43141807537486
# (Device-74)Median Round Trip Time = 152.01754200001005
# (Device-74)Standard deviation  Round Trip Time = 7.9619642844710885
# (Device-74)Min Round Trip Time = 149.10399500001859
# (Device-74)Max Round Trip Time = 253.2045820000235
# ---------------------------------------------------------------
# (Device-75)Mean Round Trip Time = 145.3666272261326
# (Device-75)Median Round Trip Time = 144.35857500006932
# (Device-75)Standard deviation  Round Trip Time = 3.287948741769954
# (Device-75)Min Round Trip Time = 141.82129999994686
# (Device-75)Max Round Trip Time = 160.4534479999984
# ---------------------------------------------------------------
# (Device-76)Mean Round Trip Time = 154.09904706029897
# (Device-76)Median Round Trip Time = 152.9451409999183
# (Device-76)Standard deviation  Round Trip Time = 4.370029368851436
# (Device-76)Min Round Trip Time = 150.0355579999848
# (Device-76)Max Round Trip Time = 193.77155199998697
# ---------------------------------------------------------------
# (Device-77)Mean Round Trip Time = 145.80688718592532
# (Device-77)Median Round Trip Time = 145.12367800000447
# (Device-77)Standard deviation  Round Trip Time = 3.3072637337912196
# (Device-77)Min Round Trip Time = 142.2300130000167
# (Device-77)Max Round Trip Time = 168.25676000001977
# ---------------------------------------------------------------
# (Device-78)Mean Round Trip Time = 148.1104434723628
# (Device-78)Median Round Trip Time = 147.08285199998272
# (Device-78)Standard deviation  Round Trip Time = 4.300818001193118
# (Device-78)Min Round Trip Time = 143.67118899997422
# (Device-78)Max Round Trip Time = 188.06209900003523
# ---------------------------------------------------------------
# (Device-79)Mean Round Trip Time = 147.37627607538073
# (Device-79)Median Round Trip Time = 146.65126900001724
# (Device-79)Standard deviation  Round Trip Time = 2.7568057889112367
# (Device-79)Min Round Trip Time = 143.68183900000986
# (Device-79)Max Round Trip Time = 156.7443799999637
# ---------------------------------------------------------------
# (Device-80)Mean Round Trip Time = 145.02789930653023
# (Device-80)Median Round Trip Time = 144.42697900000212
# (Device-80)Standard deviation  Round Trip Time = 3.0775662860805006
# (Device-80)Min Round Trip Time = 141.5468029999829
# (Device-80)Max Round Trip Time = 157.63685000001715
# ---------------------------------------------------------------
# (Device-81)Mean Round Trip Time = 153.12216341708378
# (Device-81)Median Round Trip Time = 152.5355109999964
# (Device-81)Standard deviation  Round Trip Time = 3.0886751693183516
# (Device-81)Min Round Trip Time = 149.5619480000414
# (Device-81)Max Round Trip Time = 169.04756599998905
# ---------------------------------------------------------------
# (Device-82)Mean Round Trip Time = 153.47498405527801
# (Device-82)Median Round Trip Time = 152.53393400007553
# (Device-82)Standard deviation  Round Trip Time = 3.589487007606161
# (Device-82)Min Round Trip Time = 149.9882219999904
# (Device-82)Max Round Trip Time = 169.77986099999498
# ---------------------------------------------------------------
# (Device-83)Mean Round Trip Time = 152.69140514572382
# (Device-83)Median Round Trip Time = 151.36145399998213
# (Device-83)Standard deviation  Round Trip Time = 8.138962685033054
# (Device-83)Min Round Trip Time = 145.46221800003423
# (Device-83)Max Round Trip Time = 242.33610700002828
# ---------------------------------------------------------------
# (Device-84)Mean Round Trip Time = 145.31637234171157
# (Device-84)Median Round Trip Time = 144.67808099999502
# (Device-84)Standard deviation  Round Trip Time = 3.1921854725406242
# (Device-84)Min Round Trip Time = 141.938467999978
# (Device-84)Max Round Trip Time = 161.3621839999837
# ---------------------------------------------------------------
# (Device-85)Mean Round Trip Time = 151.622108974876
# (Device-85)Median Round Trip Time = 150.88106100000687
# (Device-85)Standard deviation  Round Trip Time = 5.322622914928364
# (Device-85)Min Round Trip Time = 147.1931909999853
# (Device-85)Max Round Trip Time = 218.27873000000864
# ---------------------------------------------------------------
# (Device-86)Mean Round Trip Time = 144.97021131156
# (Device-86)Median Round Trip Time = 143.89946799997233
# (Device-86)Standard deviation  Round Trip Time = 5.181908804750461
# (Device-86)Min Round Trip Time = 141.4316519999943
# (Device-86)Max Round Trip Time = 192.62029700007588
# ---------------------------------------------------------------
# (Device-87)Mean Round Trip Time = 145.94416086431946
# (Device-87)Median Round Trip Time = 144.8226150000096
# (Device-87)Standard deviation  Round Trip Time = 5.343273590820701
# (Device-87)Min Round Trip Time = 142.08718800000497
# (Device-87)Max Round Trip Time = 204.22958299997163
# ---------------------------------------------------------------
# (Device-88)Mean Round Trip Time = 159.942872452262
# (Device-88)Median Round Trip Time = 159.21958600000607
# (Device-88)Standard deviation  Round Trip Time = 2.8207023844986896
# (Device-88)Min Round Trip Time = 156.33757400007653
# (Device-88)Max Round Trip Time = 171.37383499999714
# ---------------------------------------------------------------
# (Device-89)Mean Round Trip Time = 151.1757722412065
# (Device-89)Median Round Trip Time = 150.5120240000224
# (Device-89)Standard deviation  Round Trip Time = 2.7296101325490465
# (Device-89)Min Round Trip Time = 145.09162500002049
# (Device-89)Max Round Trip Time = 159.42425599996568
# ---------------------------------------------------------------
# (Device-90)Mean Round Trip Time = 152.91642953266083
# (Device-90)Median Round Trip Time = 152.1220329999835
# (Device-90)Standard deviation  Round Trip Time = 3.256393202768627
# (Device-90)Min Round Trip Time = 147.846096999956
# (Device-90)Max Round Trip Time = 179.1707539999834
# ---------------------------------------------------------------
# (Device-91)Mean Round Trip Time = 154.63192428140843
# (Device-91)Median Round Trip Time = 153.43485699997927
# (Device-91)Standard deviation  Round Trip Time = 6.010820282097165
# (Device-91)Min Round Trip Time = 150.71976199999426
# (Device-91)Max Round Trip Time = 223.35417300001836
# ---------------------------------------------------------------
# (Device-92)Mean Round Trip Time = 153.24950574874623
# (Device-92)Median Round Trip Time = 152.52582299999062
# (Device-92)Standard deviation  Round Trip Time = 3.0519751707865694
# (Device-92)Min Round Trip Time = 149.78863600003933
# (Device-92)Max Round Trip Time = 165.52280500002325
# ---------------------------------------------------------------
# (Device-93)Mean Round Trip Time = 161.2019691256238
# (Device-93)Median Round Trip Time = 160.3850940000484
# (Device-93)Standard deviation  Round Trip Time = 3.0385606927328035
# (Device-93)Min Round Trip Time = 158.07789099994807
# (Device-93)Max Round Trip Time = 182.00158199999805
# ---------------------------------------------------------------
# (Device-94)Mean Round Trip Time = 161.50158157286623
# (Device-94)Median Round Trip Time = 160.39134999994076
# (Device-94)Standard deviation  Round Trip Time = 3.473414742068332
# (Device-94)Min Round Trip Time = 157.6179509999065
# (Device-94)Max Round Trip Time = 177.75292800001807
# ---------------------------------------------------------------
# (Device-95)Mean Round Trip Time = 153.0083607688389
# (Device-95)Median Round Trip Time = 151.95366900002227
# (Device-95)Standard deviation  Round Trip Time = 4.465572789854729
# (Device-95)Min Round Trip Time = 149.44443799998908
# (Device-95)Max Round Trip Time = 194.59061099996688
# ---------------------------------------------------------------
# (Device-96)Mean Round Trip Time = 153.7588028743739
# (Device-96)Median Round Trip Time = 152.73020499998324
# (Device-96)Standard deviation  Round Trip Time = 5.445135732727324
# (Device-96)Min Round Trip Time = 149.6788100000117
# (Device-96)Max Round Trip Time = 212.98663800001805
# ---------------------------------------------------------------
# (Device-97)Mean Round Trip Time = 160.92958680402367
# (Device-97)Median Round Trip Time = 159.95431299995744
# (Device-97)Standard deviation  Round Trip Time = 4.020382503694664
# (Device-97)Min Round Trip Time = 157.39302099996166
# (Device-97)Max Round Trip Time = 199.8996629999965
# ---------------------------------------------------------------
# (Device-98)Mean Round Trip Time = 146.64823282914247
# (Device-98)Median Round Trip Time = 145.2762199999711
# (Device-98)Standard deviation  Round Trip Time = 7.473638929380605
# (Device-98)Min Round Trip Time = 142.2641599999679
# (Device-98)Max Round Trip Time = 239.6494370000255
# ---------------------------------------------------------------
# (Device-99)Mean Round Trip Time = 154.1578673969844
# (Device-99)Median Round Trip Time = 153.15026600001147
# (Device-99)Standard deviation  Round Trip Time = 4.874028182631246
# (Device-99)Min Round Trip Time = 150.11769399995956
# (Device-99)Max Round Trip Time = 205.17562300000236
# ---------------------------------------------------------------
# (Device-100)Mean Round Trip Time = 145.3814083115551
# (Device-100)Median Round Trip Time = 144.23326100001077
# (Device-100)Standard deviation  Round Trip Time = 3.3774444994232202
# (Device-100)Min Round Trip Time = 141.93308500000512
# (Device-100)Max Round Trip Time = 160.87846199999944
# ---------------------------------------------------------------

# %% [markdown]
# # CÁLCULO DO TAMANHO DA AMOSTRA

# %%
nivel_de_significancia = 0.05

# %%
nivel_de_confiança = 1 - nivel_de_significancia
nivel_de_confiança
# Out:
# 0.95

# %%
#Calculando o z com scipy
z = scipy.stats.norm.ppf(0.975)
z
# Out:
# 1.959963984540054

# %% [markdown]
# Com nosso z calculado podemos seguir adiante
#
# ### $$z = 1.959963984540054 $$
#
# Abaixo segue algumas formulas que iremos utilizar para calcular o numero de amostra

# %% [markdown]
# ### Calculando o tamanho da nossa amostra

# %%
df_concatenado = pd.concat(data.values())
desvio_padrao_amostral = df_concatenado["RTT"].std()
media = df_concatenado["RTT"].mean()
e = 0.05 * media
n = (z * ( desvio_padrao_amostral/e) )**2
n
# Out:
# 4.8320090411675345

# %%
e = df_concatenado["RTT"].mean() * 0.05

# %%
desvio_padrao_amostral
# Out:
# 8.602058790923419

# %%
import matplotlib 
i=1
fig, ax = plt.subplots(figsize=(10,5),dpi=72)
for port in ports:
  ax.scatter(data[port]["RTT"].index,data[port]["RTT"], label='Dispositivo-{}'.format(i))
  ax.set_ylabel('Round Trip Time (ms)')
  ax.set_xlabel('Quantidade de Publicação')
  ax.set_title('Gráfico de dispersão (Round Trip Time)')
#   ax.hlines(data[port]["RTT"].max(),  xmin=0, xmax=620, colors="red", linestyles="dashed", label="Maior Medição")
#   ax.hlines(data[port]["RTT"].min(),  xmin=0, xmax=620, colors="green", linestyles="dashed", label="Menor Medição")
  ax.legend()
  i+=1

# %%
df_concatenado["RTT"].mean()
# Out:
# 153.39691446608037

# %%
df_concatenado["RTT"].to_csv("dados.csv", index=False)
